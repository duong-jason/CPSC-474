# %%
import pickle
import numpy as np
import pandas as pd
from pathlib import Path
from copy import deepcopy
from statistics import mode
from optbinning import OptimalBinning

from sklearn.metrics import confusion_matrix
from sklearn.datasets import load_breast_cancer

pd.set_option('mode.chained_assignment', None)

# %%
debug = 0

# %%
data = load_breast_cancer(as_frame=True)
X, y = data.data, data.target

# %% [markdown]
# # Data Preprocessing
# Source: http://gnpalencia.org/optbinning/tutorials/tutorial_binary.html

# %%
for d in X.columns:
    op = OptimalBinning(name=d, dtype="numerical", solver="cp")
    op.fit(X[d].values, y)
    bins = [0] + list(op.splits) + [X[d].max()]
    X[d] = pd.cut(X[d], bins, labels=range(len(bins)-1))

# %%
for d in ['mean concavity', 'mean concave points', 'concavity error', 'concave points error', 'worst concavity', 'worst concave points']:
    X[d].fillna(mode(X[d].values), inplace=True)

# %%
path = Path(r'/home/jason/Desktop/school/dc/distrf/dataset/cancer.pkl')

df = pd.concat([X, y], axis=1)
df.to_pickle(path)

# %%
df = pd.read_pickle(path)
X, y = df.iloc[:, :-1], df.iloc[:, -1]

# %% [markdown]
# # Train-Test Split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)

# %% [markdown]
# # Decision Tree Implementation
# ### Entropy *(Bits)*
# $\mathcal{H}(t, \mathcal{D})=-\sum_{I\in levels(t)\\}^{}{P(t=I)\cdot\log_2(P(t=I))}$
#
# ### Rem
# $rem(d,\mathcal{D})=\sum_{I\in levels(t)}{}\frac{|\mathcal{D}_{d=I}|}{\mathcal{D}}\cdot \mathcal{H}(t, \mathcal{D}_{d=I})$
#
# ### Information Gain
# $IG(d, \mathcal{D})=\mathcal{H}(t, \mathcal{D})-rem(d, \mathcal{D})$

# %%
class Node:
    def __init__(
        self,
        *,
        feature=None,
        data=None,
        branch=None,
        parent=None,
        leaf=False,
        children=[]
    ):
        self.feature = feature
        self.data = data
        self.branch = branch
        self.parent = parent
        self.leaf = leaf
        self.children = children

    @property
    def isLeaf(self):
        return self.leaf

    @property
    def X(self):
        return self.data.iloc[:, :-1]

    @property
    def y(self):
        return self.data.iloc[:, -1]

# %%
class DecisionTree:
    """A Rudimentary Decision Tree Classifier"""
    def __init__(self, *, criterion=None):
        """
        Pre-pruning criterion = {max_depth, partition_threshold, low_gain}
        """
        self.root = None
        self.levels = None
        self.criterion = criterion

    def __repr__(self, node=None, depth=0):
        """Displays the decision tree"""
        if not node:
            node = self.root

        print(depth * '\t', node.feature, f"(Branch={node.branch})")
        for child in node.children:
            self.__repr__(child, depth+1)

        return ""

    def partition(self, X, y, d, t):
        D = pd.concat([X.loc[X[d]==t], y.loc[X[d]==t]], axis=1)
        D = D.drop([d], axis=1)
        return D.iloc[:, :-1], D.iloc[:, -1], t

    def entropy(self, X, y):
        """Measures the amount of uncertainty/impurity/heterogeneity in (X, y)"""
        proba = lambda t: len(X.loc[y==t]) / len(X)
        return -sum([proba(t) * np.log2(proba(t)) for t in y.unique()])

    def rem(self, X, y, d):
        """Measures the entropy after partitioning (X, y) on feature (d)"""
        weight = lambda t: len(X.loc[X[d]==t]) / len(X)
        return sum([weight(t) * self.entropy(X.loc[X[d]==t], y.loc[X[d]==t]) for t in X[d].unique()])

    def information_gain(self, X, y, d):
        """Measures the reduction in the overall entropy in (X, y) achieved by testing on feature (d)"""
        if debug:
            print(f"{d} = {self.entropy(X, y):.3f} - {self.rem(X, y, d):.3f} = {self.entropy(X, y) - self.rem(X, y, d):.3f}") 

        return self.entropy(X, y) - self.rem(X, y, d)

    def build_tree(self, X, y, *, parent=None, branch=None, depth=0):
        """Performs the ID3 algorithm"""
        if len(y.unique()) == 1:  # all instances have the same target feature values
            if debug:
                print("All instances have the same target feature value\n")
            return Node(feature=y.iat[0],
                        data=pd.concat([X, y], axis=1),
                        branch=branch,
                        parent=parent,
                        leaf=True)
        elif X.empty:  # dataset is empty, return a leaf node labeled with the majority class of the parent
            if debug:
                print("Dataset is empty\n")
            return Node(feature=mode(parent.y),
                        branch=branch,
                        parent=parent,
                        leaf=True)
        elif all((X[d] == X[d].iloc[0]).all() for d in X.columns):  # if all feature values are identical
            if debug:
                print("All instances have the same descriptive features\n")
                return Node(feature=mode(y),
                            data=pd.concat([X, y], axis=1),
                            branch=branch,
                            parent=parent,
                            leaf=True)
        elif self.criterion.get("max_depth"):
            if depth >= self.criterion["max_depth"]:
                if debug:
                    print("Stopping at Max Depth\n")
                return Node(feature=mode(y),
                            data=pd.concat([X, y], axis=1),
                            branch=branch,
                            parent=parent,
                            leaf=True)
        elif self.criterion.get("partition_threshold"):
            if len(X) < self.criterion["partition_threshold"]:
                if debug:
                    print(f"Stopping at {len(X)} instances\n")
                return Node(feature=mode(y),
                            data=pd.concat([X, y], axis=1),
                            branch=branch,
                            parent=parent,
                            leaf=True)

        if debug:
            print("===Information Gain===")

        gain = np.argmax([self.information_gain(X, y, d) for d in X.columns])

        if self.criterion.get('low_gain'):
            if gain <= self.criterion["low_gain"]:
                if debug:
                    print(f"Stopping at Gain={gain}\n")
                return Node(feature=mode(y),
                            data=pd.concat([X, y], axis=1),
                            branch=branch,
                            parent=parent,
                            leaf=True)

        best_feature = X.columns[gain]
        best_node = deepcopy(Node(feature=best_feature,
                                  data=pd.concat([X, y], axis=1),
                                  branch=branch,
                                  parent=parent))

        if debug:
            print()
            print("===Best Feature===")
            print(best_feature)
            print()

        partitions = [self.partition(X, y, best_feature, t) for t in self.levels[best_feature]]

        for *d, t in partitions:
            if debug:
                print(f"===Partitioned Dataset ({t})===")
                print(pd.concat(d, axis=1).head())
                print()
            best_node.children.append(self.build_tree(*d, parent=best_node, branch=t, depth=depth+1))
        return best_node

    def fit(self, X, y):
        self.levels = {k: X[k].unique() for k in X.columns}
        self.root = self.build_tree(X, y)
        return self

    def predict(self, x):
        node = self.root
        while not node.isLeaf:
            for child in node.children:
                if child.branch == x.get(node.feature).values:
                    node = child
                    break
        return node.feature

    def score(self, X, y):
        y_hat = [self.predict(X.iloc[x].to_frame().T) for x in range(len(X))]
        return confusion_matrix(y, y_hat, labels=[1, 0])

# %%
# %%time
dt = DecisionTree(criterion={'low_gain': 5e-2}).fit(X_train, y_train)
# Out:
# ===Information Gain===
# mean radius = 0.964 - 0.454 = 0.510
# mean texture = 0.964 - 0.737 = 0.227
# mean perimeter = 0.964 - 0.427 = 0.537
# mean area = 0.964 - 0.448 = 0.516
# mean smoothness = 0.964 - 0.843 = 0.121
# mean compactness = 0.964 - 0.662 = 0.302
# mean concavity = 0.964 - 0.460 = 0.503
# mean concave points = 0.964 - 0.373 = 0.590
# mean symmetry = 0.964 - 0.837 = 0.127
# mean fractal dimension = 0.964 - 0.929 = 0.034
# radius error = 0.964 - 0.626 = 0.338
# texture error = 0.964 - 0.927 = 0.037
# perimeter error = 0.964 - 0.618 = 0.345
# area error = 0.964 - 0.483 = 0.481
# smoothness error = 0.964 - 0.937 = 0.026
# compactness error = 0.964 - 0.836 = 0.127
# concavity error = 0.964 - 0.769 = 0.195
# concave points error = 0.964 - 0.773 = 0.191
# symmetry error = 0.964 - 0.923 = 0.041
# fractal dimension error = 0.964 - 0.888 = 0.076
# worst radius = 0.964 - 0.316 = 0.648
# worst texture = 0.964 - 0.761 = 0.202
# worst perimeter = 0.964 - 0.304 = 0.660
# worst area = 0.964 - 0.307 = 0.656
# worst smoothness = 0.964 - 0.804 = 0.160
# worst compactness = 0.964 - 0.646 = 0.318
# worst concavity = 0.964 - 0.479 = 0.485
# worst concave points = 0.964 - 0.366 = 0.597
# worst symmetry = 0.964 - 0.784 = 0.180
# worst fractal dimension = 0.964 - 0.854 = 0.110
#
# ===Best Feature===
# worst perimeter
#
# ===Partitioned Dataset (1)===
#     mean radius mean texture mean perimeter mean area mean smoothness  \
# 383           2            3              1         2               3
# 51            3            1              3         3               0
# 480           1            3              1         2               2
# 111           2            6              2         2               2
# 397           2            3              2         2               0
#
#     mean compactness mean concavity mean concave points mean symmetry  \
# 383                4              1                   1             3
# 51                 1              0                   0             0
# 480                1              0                   0             1
# 111                3              4                   4             3
# 397                2              2                   2             2
#
#     mean fractal dimension  ... worst radius worst texture worst area  \
# 383                      7  ...            1             3          1
# 51                       6  ...            1             3          1
# 480                      7  ...            1             7          0
# 111                      8  ...            1             5          0
# 397                      4  ...            1             2          1
#
#     worst smoothness worst compactness worst concavity worst concave points  \
# 383                5                 6               4                    2
# 51                 1                 2               0                    2
# 480                2                 4               1                    0
# 111                3                 4               2                    3
# 397                0                 3               1                    1
#
#     worst symmetry worst fractal dimension target
# 383              4                       6      1
# 51               1                       2      1
# 480              1                       1      1
# 111              0                       3      1
# 397              0                       0      1
#
# [5 rows x 30 columns]
#
# ===Information Gain===
# mean radius = 0.276 - 0.199 = 0.077
# mean texture = 0.276 - 0.135 = 0.141
# mean perimeter = 0.276 - 0.225 = 0.051
# mean area = 0.276 - 0.119 = 0.157
# mean smoothness = 0.276 - 0.170 = 0.106
# mean compactness = 0.276 - 0.087 = 0.189
# mean concavity = 0.276 - 0.084 = 0.192
# mean concave points = 0.276 - 0.108 = 0.168
# mean symmetry = 0.276 - 0.184 = 0.092
# mean fractal dimension = 0.276 - 0.101 = 0.175
# radius error = 0.276 - 0.178 = 0.098
# texture error = 0.276 - 0.213 = 0.063
# perimeter error = 0.276 - 0.196 = 0.080
# area error = 0.276 - 0.172 = 0.104
# smoothness error = 0.276 - 0.224 = 0.053
# compactness error = 0.276 - 0.170 = 0.106
# concavity error = 0.276 - 0.175 = 0.101
# concave points error = 0.276 - 0.115 = 0.161
# symmetry error = 0.276 - 0.095 = 0.182
# fractal dimension error = 0.276 - 0.192 = 0.084
# worst radius = 0.276 - 0.264 = 0.012
# worst texture = 0.276 - 0.166 = 0.110
# worst area = 0.276 - 0.254 = 0.022
# worst smoothness = 0.276 - 0.135 = 0.141
# worst compactness = 0.276 - 0.086 = 0.190
# worst concavity = 0.276 - 0.118 = 0.159
# worst concave points = 0.276 - 0.119 = 0.158
# worst symmetry = 0.276 - 0.098 = 0.178
# worst fractal dimension = 0.276 - 0.127 = 0.149
#
# ===Best Feature===
# mean concavity
#
# ===Partitioned Dataset (1)===
#     mean radius mean texture mean perimeter mean area mean smoothness  \
# 383           2            3              1         2               3
# 394           1            3              1         2               3
# 482           3            0              3         3               3
# 475           2            1              2         2               2
# 292           2            1              2         2               3
#
#     mean compactness mean concave points mean symmetry mean fractal dimension  \
# 383                4                   1             3                      7
# 394                2                   2             5                      7
# 482                3                   4             3                      7
# 475                1                   1             2                      5
# 292                1                   2             3                      7
#
#     radius error  ... worst radius worst texture worst area worst smoothness  \
# 383            1  ...            1             3          1                5
# 394            2  ...            1             5          1                5
# 482            0  ...            1             0          1                4
# 475            0  ...            1             1          1                3
# 292            0  ...            1             1          1                5
#
#     worst compactness worst concavity worst concave points worst symmetry  \
# 383                 6               4                    2              4
# 394                 3               1                    0              5
# 482                 4               1                    3              6
# 475                 4               4                    2              5
# 292                 4               2                    2              6
#
#     worst fractal dimension target
# 383                       6      1
# 394                       0      1
# 482                       5      1
# 475                       1      1
# 292                       5      1
#
# [5 rows x 29 columns]
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (6)===
#     mean radius mean texture mean perimeter mean area mean smoothness  \
# 9             2            9              2         2               5
# 146           1            2              1         1               4
# 3             0            6              1         0               5
#
#     mean compactness mean concave points mean symmetry mean fractal dimension  \
# 9                  6                   6             5                      9
# 146                5                   5             6                      9
# 3                  6                   6             6                      9
#
#     radius error  ... worst radius worst texture worst area worst smoothness  \
# 9              2  ...            2             9          2                7
# 146            2  ...            1             6          1                4
# 3              4  ...            1             6          1                7
#
#     worst compactness worst concavity worst concave points worst symmetry  \
# 9                   8               6                    5              8
# 146                 7               5                    5              8
# 3                   8               6                    5              8
#
#     worst fractal dimension target
# 9                         7      0
# 146                       6      0
# 3                         7      0
#
# [3 rows x 29 columns]
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (0)===
#     mean radius mean texture mean perimeter mean area mean smoothness  \
# 51            3            1              3         3               0
# 480           1            3              1         2               2
# 544           4            6              3         4               2
# 543           3           10              2         3               1
# 326           4            0              3         4               2
#
#     mean compactness mean concave points mean symmetry mean fractal dimension  \
# 51                 1                   0             0                      6
# 480                1                   0             1                      7
# 544                2                   1             2                      8
# 543                1                   2             2                      4
# 326                0                   1             0                      3
#
#     radius error  ... worst radius worst texture worst area worst smoothness  \
# 51             0  ...            1             3          1                1
# 480            0  ...            1             7          0                2
# 544            1  ...            2             4          1                3
# 543            1  ...            1             9          1                1
# 326            1  ...            2             0          3                3
#
#     worst compactness worst concavity worst concave points worst symmetry  \
# 51                  2               0                    2              1
# 480                 4               1                    0              1
# 544                 3               0                    0              1
# 543                 2               0                    1              2
# 326                 1               0                    0              0
#
#     worst fractal dimension target
# 51                        2      1
# 480                       1      1
# 544                       3      1
# 543                       0      1
# 326                       0      1
#
# [5 rows x 29 columns]
#
# ===Information Gain===
# mean radius = 0.141 - 0.104 = 0.037
# mean texture = 0.141 - 0.040 = 0.101
# mean perimeter = 0.141 - 0.055 = 0.086
# mean area = 0.141 - 0.000 = 0.141
# mean smoothness = 0.141 - 0.111 = 0.030
# mean compactness = 0.141 - 0.106 = 0.035
# mean concave points = 0.141 - 0.104 = 0.037
# mean symmetry = 0.141 - 0.116 = 0.025
# mean fractal dimension = 0.141 - 0.072 = 0.069
# radius error = 0.141 - 0.040 = 0.101
# texture error = 0.141 - 0.072 = 0.069
# perimeter error = 0.141 - 0.040 = 0.101
# area error = 0.141 - 0.040 = 0.101
# smoothness error = 0.141 - 0.065 = 0.077
# compactness error = 0.141 - 0.115 = 0.027
# concavity error = 0.141 - 0.097 = 0.045
# concave points error = 0.141 - 0.000 = 0.141
# symmetry error = 0.141 - 0.040 = 0.101
# fractal dimension error = 0.141 - 0.119 = 0.023
# worst radius = 0.141 - 0.106 = 0.035
# worst texture = 0.141 - 0.055 = 0.086
# worst area = 0.141 - 0.102 = 0.040
# worst smoothness = 0.141 - 0.087 = 0.054
# worst compactness = 0.141 - 0.072 = 0.069
# worst concavity = 0.141 - 0.130 = 0.011
# worst concave points = 0.141 - 0.130 = 0.011
# worst symmetry = 0.141 - 0.087 = 0.054
# worst fractal dimension = 0.141 - 0.126 = 0.016
#
# ===Best Feature===
# mean area
#
# ===Partitioned Dataset (2)===
#     mean radius mean texture mean perimeter mean smoothness mean compactness  \
# 480           1            3              1               2                1
# 362           2            4              2               2                1
# 84            1            1              1               2                1
# 294           2            0              2               2                2
# 325           2            3              1               3                1
#
#     mean concave points mean symmetry mean fractal dimension radius error  \
# 480                   0             1                      7            0
# 362                   0             3                      7            0
# 84                    0             5                      6            0
# 294                   0             2                      7            0
# 325                   0             2                      6            0
#
#     texture error  ... worst radius worst texture worst area worst smoothness  \
# 480             5  ...            1             7          0                2
# 362             5  ...            1             6          1                3
# 84              5  ...            1             5          1                4
# 294             1  ...            1             0          1                3
# 325             2  ...            1             2          1                4
#
#     worst compactness worst concavity worst concave points worst symmetry  \
# 480                 4               1                    0              1
# 362                 3               0                    1              3
# 84                  3               2                    1              6
# 294                 2               0                    0              1
# 325                 2               0                    0              3
#
#     worst fractal dimension target
# 480                       1      1
# 362                       0      1
# 84                        2      1
# 294                       0      1
# 325                       0      1
#
# [5 rows x 28 columns]
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (6)===
# Empty DataFrame
# Columns: [mean radius, mean texture, mean perimeter, mean smoothness, mean compactness, mean concave points, mean symmetry, mean fractal dimension, radius error, texture error, perimeter error, area error, smoothness error, compactness error, concavity error, concave points error, symmetry error, fractal dimension error, worst radius, worst texture, worst area, worst smoothness, worst compactness, worst concavity, worst concave points, worst symmetry, worst fractal dimension, target]
# Index: []
#
# [0 rows x 28 columns]
#
# Dataset is empty
#
# ===Partitioned Dataset (3)===
#     mean radius mean texture mean perimeter mean smoothness mean compactness  \
# 51            3            1              3               0                1
# 543           3           10              2               1                1
# 377           3           10              3               0                0
# 246           3            3              2               0                0
# 455           3           10              3               2                1
#
#     mean concave points mean symmetry mean fractal dimension radius error  \
# 51                    0             0                      6            0
# 543                   2             2                      4            1
# 377                   0             0                      4            0
# 246                   0             1                      2            0
# 455                   2             0                      6            2
#
#     texture error  ... worst radius worst texture worst area worst smoothness  \
# 51              2  ...            1             3          1                1
# 543             7  ...            1             9          1                1
# 377             5  ...            1             9          1                1
# 246             7  ...            1             7          1                1
# 455             8  ...            2             9          2                2
#
#     worst compactness worst concavity worst concave points worst symmetry  \
# 51                  2               0                    2              1
# 543                 2               0                    1              2
# 377                 2               0                    0              3
# 246                 2               2                    0              3
# 455                 2               0                    1              0
#
#     worst fractal dimension target
# 51                        2      1
# 543                       0      1
# 377                       0      1
# 246                       0      1
# 455                       1      1
#
# [5 rows x 28 columns]
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (5)===
#    mean radius mean texture mean perimeter mean smoothness mean compactness  \
# 38           4            9              4               2                0
#
#    mean concave points mean symmetry mean fractal dimension radius error  \
# 38                   1             2                      1            6
#
#    texture error  ... worst radius worst texture worst area worst smoothness  \
# 38             8  ...            2             5          2                0
#
#    worst compactness worst concavity worst concave points worst symmetry  \
# 38                 0               0                    0              0
#
#    worst fractal dimension target
# 38                       0      0
#
# [1 rows x 28 columns]
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (0)===
# Empty DataFrame
# Columns: [mean radius, mean texture, mean perimeter, mean smoothness, mean compactness, mean concave points, mean symmetry, mean fractal dimension, radius error, texture error, perimeter error, area error, smoothness error, compactness error, concavity error, concave points error, symmetry error, fractal dimension error, worst radius, worst texture, worst area, worst smoothness, worst compactness, worst concavity, worst concave points, worst symmetry, worst fractal dimension, target]
# Index: []
#
# [0 rows x 28 columns]
#
# Dataset is empty
#
# ===Partitioned Dataset (4)===
#     mean radius mean texture mean perimeter mean smoothness mean compactness  \
# 544           4            6              3               2                2
# 326           4            0              3               2                0
# 357           4            1              3               1                0
# 438           4            5              3               1                1
# 560           4           10              4               2                3
#
#     mean concave points mean symmetry mean fractal dimension radius error  \
# 544                   1             2                      8            1
# 326                   1             0                      3            1
# 357                   0             0                      5            1
# 438                   0             2                      3            2
# 560                   3             1                      7            2
#
#     texture error  ... worst radius worst texture worst area worst smoothness  \
# 544             4  ...            2             4          1                3
# 326             5  ...            2             0          3                3
# 357             6  ...            2             5          2                2
# 438             8  ...            2             7          3                1
# 560             7  ...            2             9          2                3
#
#     worst compactness worst concavity worst concave points worst symmetry  \
# 544                 3               0                    0              1
# 326                 1               0                    0              0
# 357                 1               0                    0              1
# 438                 1               0                    0              2
# 560                 4               0                    2              1
#
#     worst fractal dimension target
# 544                       3      1
# 326                       0      1
# 357                       0      1
# 438                       0      1
# 560                       3      1
#
# [5 rows x 28 columns]
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (1)===
#     mean radius mean texture mean perimeter mean smoothness mean compactness  \
# 115           1            6              1               2                1
#
#     mean concave points mean symmetry mean fractal dimension radius error  \
# 115                   0             2                      7            2
#
#     texture error  ... worst radius worst texture worst area worst smoothness  \
# 115             2  ...            1             6          1                6
#
#     worst compactness worst concavity worst concave points worst symmetry  \
# 115                 4               1                    0              2
#
#     worst fractal dimension target
# 115                       3      1
#
# [1 rows x 28 columns]
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (4)===
#     mean radius mean texture mean perimeter mean area mean smoothness  \
# 111           2            6              2         2               2
# 466           3            6              3         3               1
# 81            3            1              3         2               3
#
#     mean compactness mean concave points mean symmetry mean fractal dimension  \
# 111                3                   4             3                      8
# 466                3                   2             2                      6
# 81                 4                   5             5                      8
#
#     radius error  ... worst radius worst texture worst area worst smoothness  \
# 111            2  ...            1             5          0                3
# 466            2  ...            1             5          1                3
# 81             2  ...            2             3          1                6
#
#     worst compactness worst concavity worst concave points worst symmetry  \
# 111                 4               2                    3              0
# 466                 6               5                    3              2
# 81                  7               5                    5              6
#
#     worst fractal dimension target
# 111                       3      1
# 466                       2      1
# 81                        6      1
#
# [3 rows x 29 columns]
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (5)===
#     mean radius mean texture mean perimeter mean area mean smoothness  \
# 485           2            2              2         2               2
#
#     mean compactness mean concave points mean symmetry mean fractal dimension  \
# 485                4                   3             5                      9
#
#     radius error  ... worst radius worst texture worst area worst smoothness  \
# 485            3  ...            1             2          1                2
#
#     worst compactness worst concavity worst concave points worst symmetry  \
# 485                 7               5                    3              6
#
#     worst fractal dimension target
# 485                       6      1
#
# [1 rows x 29 columns]
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (2)===
#     mean radius mean texture mean perimeter mean area mean smoothness  \
# 397           2            3              2         2               0
# 431           2            3              1         2               3
# 204           2            4              1         2               2
# 496           2            3              2         2               3
# 396           3            4              3         3               3
#
#     mean compactness mean concave points mean symmetry mean fractal dimension  \
# 397                2                   2             2                      4
# 431                4                   1             4                      8
# 204                3                   2             5                      7
# 496                4                   3             2                      8
# 396                3                   4             4                      7
#
#     radius error  ... worst radius worst texture worst area worst smoothness  \
# 397            2  ...            1             2          1                0
# 431            0  ...            0             3          0                5
# 204            3  ...            1             4          1                5
# 496            1  ...            1             3          1                6
# 396            0  ...            1             6          1                5
#
#     worst compactness worst concavity worst concave points worst symmetry  \
# 397                 3               1                    1              0
# 431                 4               2                    0              2
# 204                 4               3                    2              5
# 496                 7               4                    3              6
# 396                 4               4                    4              3
#
#     worst fractal dimension target
# 397                       0      1
# 431                       5      1
# 204                       3      1
# 496                       6      1
# 396                       1      1
#
# [5 rows x 29 columns]
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (3)===
#     mean radius mean texture mean perimeter mean area mean smoothness  \
# 423           3            4              3         3               2
# 528           4            0              4         4               5
# 469           1            3              1         1               5
#
#     mean compactness mean concave points mean symmetry mean fractal dimension  \
# 423                3                   3             4                      7
# 528                2                   5             5                      7
# 469                4                   4             5                      8
#
#     radius error  ... worst radius worst texture worst area worst smoothness  \
# 423            0  ...            2             5          2                2
# 528            4  ...            1             0          1                4
# 469            3  ...            1             5          0                7
#
#     worst compactness worst concavity worst concave points worst symmetry  \
# 423                 5               4                    3              3
# 528                 2               1                    2              0
# 469                 5               4                    3              3
#
#     worst fractal dimension target
# 423                       3      1
# 528                       0      1
# 469                       4      1
#
# [3 rows x 29 columns]
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (4)===
#     mean radius mean texture mean perimeter mean area mean smoothness  \
# 244           6            8              6         6               3
# 393           6            7              6         6               5
# 253           6            3              6         6               3
# 54            5            7              4         5               2
# 372           6            1              6         6               3
#
#     mean compactness mean concavity mean concave points mean symmetry  \
# 244                5              6                   6             5
# 393                6              6                   6             6
# 253                3              5                   6             4
# 54                 1              1                   2             2
# 372                4              6                   6             5
#
#     mean fractal dimension  ... worst radius worst texture worst area  \
# 244                      6  ...            5             8          5
# 393                      7  ...            5             7          5
# 253                      2  ...            5             5          5
# 54                       3  ...            4             8          4
# 372                      7  ...            5             3          5
#
#     worst smoothness worst compactness worst concavity worst concave points  \
# 244                5                 5               4                    4
# 393                6                 8               6                    5
# 253                5                 4               4                    5
# 54                 4                 4               3                    4
# 372                2                 5               5                    5
#
#     worst symmetry worst fractal dimension target
# 244              4                       1      0
# 393              7                       6      0
# 253              5                       2      0
# 54               3                       2      0
# 372              3                       3      0
#
# [5 rows x 30 columns]
#
# ===Information Gain===
# mean radius = 0.128 - 0.123 = 0.005
# mean texture = 0.128 - 0.069 = 0.060
# mean perimeter = 0.128 - 0.121 = 0.007
# mean area = 0.128 - 0.123 = 0.005
# mean smoothness = 0.128 - 0.043 = 0.085
# mean compactness = 0.128 - 0.067 = 0.062
# mean concavity = 0.128 - 0.061 = 0.068
# mean concave points = 0.128 - 0.046 = 0.082
# mean symmetry = 0.128 - 0.069 = 0.059
# mean fractal dimension = 0.128 - 0.067 = 0.062
# radius error = 0.128 - 0.091 = 0.037
# texture error = 0.128 - 0.088 = 0.040
# perimeter error = 0.128 - 0.104 = 0.025
# area error = 0.128 - 0.086 = 0.043
# smoothness error = 0.128 - 0.071 = 0.057
# compactness error = 0.128 - 0.082 = 0.047
# concavity error = 0.128 - 0.070 = 0.059
# concave points error = 0.128 - 0.083 = 0.045
# symmetry error = 0.128 - 0.099 = 0.029
# fractal dimension error = 0.128 - 0.024 = 0.104
# worst radius = 0.128 - 0.115 = 0.013
# worst texture = 0.128 - 0.083 = 0.045
# worst area = 0.128 - 0.116 = 0.012
# worst smoothness = 0.128 - 0.024 = 0.104
# worst compactness = 0.128 - 0.050 = 0.079
# worst concavity = 0.128 - 0.042 = 0.086
# worst concave points = 0.128 - 0.024 = 0.104
# worst symmetry = 0.128 - 0.080 = 0.049
# worst fractal dimension = 0.128 - 0.080 = 0.048
#
# ===Best Feature===
# fractal dimension error
#
# ===Partitioned Dataset (8)===
#     mean radius mean texture mean perimeter mean area mean smoothness  \
# 77            6            1              6         6               3
# 83            6            9              6         6               5
# 257           5            3              5         5               5
# 42            6            9              6         6               2
# 213           6            9              6         6               3
#
#     mean compactness mean concavity mean concave points mean symmetry  \
# 77                 6              6                   6             6
# 83                 5              6                   6             2
# 257                6              6                   6             6
# 42                 6              6                   6             6
# 213                3              6                   5             0
#
#     mean fractal dimension  ... worst radius worst texture worst area  \
# 77                       8  ...            5             0          5
# 83                       8  ...            5             9          5
# 257                      9  ...            4             3          4
# 42                       7  ...            5             9          5
# 213                      5  ...            4             7          4
#
#     worst smoothness worst compactness worst concavity worst concave points  \
# 77                 5                 8               5                    5
# 83                 4                 5               2                    5
# 257                7                 7               5                    5
# 42                 3                 8               6                    5
# 213                3                 3               3                    3
#
#     worst symmetry worst fractal dimension target
# 77               7                       6      0
# 83               1                       4      0
# 257              6                       7      0
# 42               8                       6      0
# 213              0                       0      0
#
# [5 rows x 29 columns]
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (5)===
#     mean radius mean texture mean perimeter mean area mean smoothness  \
# 244           6            8              6         6               3
# 393           6            7              6         6               5
# 33            6            9              6         6               2
# 441           6            9              6         6               1
# 335           6            6              6         6               4
#
#     mean compactness mean concavity mean concave points mean symmetry  \
# 244                5              6                   6             5
# 393                6              6                   6             6
# 33                 5              6                   5             4
# 441                3              5                   4             1
# 335                3              5                   6             3
#
#     mean fractal dimension  ... worst radius worst texture worst area  \
# 244                      6  ...            5             8          5
# 393                      7  ...            5             7          5
# 33                       7  ...            5             8          5
# 441                      1  ...            5             9          5
# 335                      7  ...            5             9          5
#
#     worst smoothness worst compactness worst concavity worst concave points  \
# 244                5                 5               4                    4
# 393                6                 8               6                    5
# 33                 6                 8               6                    5
# 441                5                 7               6                    5
# 335                5                 4               5                    5
#
#     worst symmetry worst fractal dimension target
# 244              4                       1      0
# 393              7                       6      0
# 33               7                       6      0
# 441              2                       2      0
# 335              2                       1      0
#
# [5 rows x 29 columns]
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (2)===
#     mean radius mean texture mean perimeter mean area mean smoothness  \
# 253           6            3              6         6               3
# 182           5            6              5         5               2
# 317           6            4              6         6               2
# 254           6            4              6         6               3
# 444           6            2              6         6               2
#
#     mean compactness mean concavity mean concave points mean symmetry  \
# 253                3              5                   6             4
# 182                2              1                   4             2
# 317                3              4                   6             4
# 254                3              5                   6             3
# 444                4              4                   4             3
#
#     mean fractal dimension  ... worst radius worst texture worst area  \
# 253                      2  ...            5             5          5
# 182                      2  ...            5             9          5
# 317                      2  ...            5             5          5
# 254                      2  ...            5             4          5
# 444                      4  ...            5             3          5
#
#     worst smoothness worst compactness worst concavity worst concave points  \
# 253                5                 4               4                    5
# 182                5                 6               3                    4
# 317                5                 4               5                    5
# 254                6                 5               5                    5
# 444                3                 4               5                    4
#
#     worst symmetry worst fractal dimension target
# 253              5                       2      0
# 182              6                       3      0
# 317              4                       3      0
# 254              6                       4      0
# 444              4                       3      0
#
# [5 rows x 29 columns]
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (1)===
#     mean radius mean texture mean perimeter mean area mean smoothness  \
# 54            5            7              4         5               2
# 368           6            3              6         6               2
# 75            5            5              5         5               2
# 134           6            7              6         6               2
# 265           6           10              6         6               2
#
#     mean compactness mean concavity mean concave points mean symmetry  \
# 54                 1              1                   2             2
# 368                2              4                   6             2
# 75                 2              3                   5             4
# 134                2              4                   5             2
# 265                3              5                   6             3
#
#     mean fractal dimension  ... worst radius worst texture worst area  \
# 54                       3  ...            4             8          4
# 368                      0  ...            5             6          5
# 75                       0  ...            5             4          5
# 134                      3  ...            5             8          5
# 265                      3  ...            5             9          5
#
#     worst smoothness worst compactness worst concavity worst concave points  \
# 54                 4                 4               3                    4
# 368                4                 2               3                    5
# 75                 6                 4               3                    4
# 134                5                 4               5                    3
# 265                5                 4               4                    5
#
#     worst symmetry worst fractal dimension target
# 54               3                       2      0
# 368              2                       0      0
# 75               3                       0      0
# 134              5                       1      0
# 265              4                       3      0
#
# [5 rows x 29 columns]
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (6)===
#     mean radius mean texture mean perimeter mean area mean smoothness  \
# 372           6            1              6         6               3
# 30            6            9              6         6               3
# 22            5            0              5         5               3
# 121           6            3              6         6               3
# 461           6            9              6         6               4
#
#     mean compactness mean concavity mean concave points mean symmetry  \
# 372                4              6                   6             5
# 30                 6              6                   6             6
# 22                 6              6                   6             6
# 121                3              5                   6             5
# 461                6              6                   6             5
#
#     mean fractal dimension  ... worst radius worst texture worst area  \
# 372                      7  ...            5             3          5
# 30                       7  ...            5             9          5
# 22                       8  ...            4             0          4
# 121                      7  ...            5             5          5
# 461                      2  ...            5             8          5
#
#     worst smoothness worst compactness worst concavity worst concave points  \
# 372                2                 5               5                    5
# 30                 6                 7               6                    5
# 22                 4                 8               6                    5
# 121                6                 4               4                    5
# 461                3                 7               6                    5
#
#     worst symmetry worst fractal dimension target
# 372              3                       3      0
# 30               6                       5      0
# 22               8                       5      0
# 121              4                       3      0
# 461              3                       0      0
#
# [5 rows x 29 columns]
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (3)===
#     mean radius mean texture mean perimeter mean area mean smoothness  \
# 207           6            6              6         6               1
# 233           6           10              6         6               2
# 274           6            9              6         6               1
# 28            5            9              5         5               3
# 180           6            7              6         6               4
#
#     mean compactness mean concavity mean concave points mean symmetry  \
# 207                1              1                   4             5
# 233                3              6                   6             1
# 274                1              1                   3             2
# 28                 5              6                   6             5
# 180                6              6                   6             4
#
#     mean fractal dimension  ... worst radius worst texture worst area  \
# 207                      0  ...            5             5          5
# 233                      2  ...            5             9          5
# 274                      1  ...            5             9          5
# 28                       7  ...            5             9          5
# 180                      4  ...            5             9          5
#
#     worst smoothness worst compactness worst concavity worst concave points  \
# 207                1                 2               1                    3
# 233                2                 4               5                    4
# 274                3                 3               2                    3
# 28                 6                 8               6                    5
# 180                5                 7               6                    5
#
#     worst symmetry worst fractal dimension target
# 207              6                       0      0
# 233              2                       3      0
# 274              2                       2      0
# 28               8                       5      0
# 180              4                       2      0
#
# [5 rows x 29 columns]
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (4)===
#     mean radius mean texture mean perimeter mean area mean smoothness  \
# 339           6            9              6         6               3
# 162           6            3              6         6               4
# 330           5            1              5         5               2
# 26            4            6              4         4               3
# 198           6            7              6         6               1
#
#     mean compactness mean concavity mean concave points mean symmetry  \
# 339                4              6                   6             4
# 162                5              6                   6             5
# 330                4              5                   5             4
# 26                 6              5                   6             6
# 198                4              4                   5             3
#
#     mean fractal dimension  ... worst radius worst texture worst area  \
# 339                      1  ...            5             8          5
# 162                      7  ...            5             6          5
# 330                      6  ...            5             3          5
# 26                       8  ...            4             9          4
# 198                      1  ...            5             8          5
#
#     worst smoothness worst compactness worst concavity worst concave points  \
# 339                6                 4               5                    5
# 162                5                 7               6                    5
# 330                5                 7               6                    5
# 26                 6                 8               6                    5
# 198                3                 8               5                    5
#
#     worst symmetry worst fractal dimension target
# 339              2                       1      0
# 162              7                       4      0
# 330              5                       4      0
# 26               8                       7      0
# 198              6                       4      0
#
# [5 rows x 29 columns]
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (7)===
#     mean radius mean texture mean perimeter mean area mean smoothness  \
# 258           5            8              6         5               4
# 15            4           10              4         4               4
# 156           6            6              6         6               4
# 563           6            9              6         6               4
# 509           5            8              5         5               5
#
#     mean compactness mean concavity mean concave points mean symmetry  \
# 258                6              6                   6             6
# 15                 5              6                   5             6
# 156                5              6                   6             5
# 563                6              6                   6             6
# 509                6              6                   6             4
#
#     mean fractal dimension  ... worst radius worst texture worst area  \
# 258                      9  ...            5             8          5
# 15                       8  ...            4             9          4
# 156                      7  ...            5             5          5
# 563                      8  ...            5             8          5
# 509                      8  ...            4             9          4
#
#     worst smoothness worst compactness worst concavity worst concave points  \
# 258                6                 8               6                    5
# 15                 7                 8               6                    5
# 156                5                 6               4                    4
# 563                5                 7               6                    5
# 509                7                 8               6                    5
#
#     worst symmetry worst fractal dimension target
# 258              6                       6      0
# 15               8                       7      0
# 156              2                       1      0
# ...
# 481                1                 2               1                    1
#
#     worst symmetry worst fractal dimension target
# 481              1                       1      1
#
# [1 rows x 28 columns]
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (5)===
#     mean radius mean texture mean perimeter mean area mean smoothness  \
# 165           4            5              4         4               1
# 298           4            3              4         4               0
# 526           3            4              3         3               3
#
#     mean compactness mean concavity mean concave points mean symmetry  \
# 165                0              0                   0             1
# 298                0              0                   0             2
# 526                3              0                   1             3
#
#     mean fractal dimension  ... fractal dimension error worst radius  \
# 165                      0  ...                       0            3
# 298                      2  ...                       1            3
# 526                      7  ...                       1            2
#
#     worst area worst smoothness worst compactness worst concavity  \
# 165          3                1                 1               0
# 298          3                0                 4               1
# 526          2                6                 5               3
#
#     worst concave points worst symmetry worst fractal dimension target
# 165                    0              3                       0      1
# 298                    1              2                       1      1
# 526                    4              6                       3      1
#
# [3 rows x 29 columns]
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (0)===
#     mean radius mean texture mean perimeter mean area mean smoothness  \
# 128           5            1              5         4               4
# 123           4            0              4         4               4
# 247           2            0              2         2               1
# 453           4            0              4         4               4
# 371           5            0              4         5               0
#
#     mean compactness mean concavity mean concave points mean symmetry  \
# 128                5              4                   6             5
# 123                3              2                   4             4
# 247                4              5                   2             2
# 453                2              1                   5             2
# 371                1              0                   1             3
#
#     mean fractal dimension  ... fractal dimension error worst radius  \
# 128                      7  ...                       7            3
# 123                      7  ...                       3            3
# 247                      7  ...                       8            1
# 453                      7  ...                       4            3
# 371                      2  ...                       1            3
#
#     worst area worst smoothness worst compactness worst concavity  \
# 128          3                4                 5               1
# 123          3                3                 3               2
# 247          1                3                 8               6
# 453          3                3                 2               0
# 371          3                2                 3               0
#
#     worst concave points worst symmetry worst fractal dimension target
# 128                    3              2                       1      1
# 123                    3              4                       2      1
# 247                    4              2                       6      1
# 453                    2              2                       1      1
# 371                    1              2                       0      1
#
# [5 rows x 29 columns]
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (9)===
#     mean radius mean texture mean perimeter mean area mean smoothness  \
# 536           4            7              4         4               3
# 238           4           10              4         4               1
# 193           2            9              1         2               3
#
#     mean compactness mean concavity mean concave points mean symmetry  \
# 536                3              5                   4             5
# 238                3              4                   3             0
# 193                4              4                   3             5
#
#     mean fractal dimension  ... fractal dimension error worst radius  \
# 536                      6  ...                       5            2
# 238                      7  ...                       4            3
# 193                      8  ...                       7            3
#
#     worst area worst smoothness worst compactness worst concavity  \
# 536          2                4                 4               5
# 238          3                1                 4               3
# 193          3                7                 7               5
#
#     worst concave points worst symmetry worst fractal dimension target
# 536                    3              3                       3      0
# 238                    1              0                       1      1
# 193                    4              6                       7      0
#
# [3 rows x 29 columns]
#
# ===Information Gain===
# mean radius = 0.918 - 0.667 = 0.252
# mean texture = 0.918 - 0.000 = 0.918
# mean perimeter = 0.918 - 0.667 = 0.252
# mean area = 0.918 - 0.667 = 0.252
# mean smoothness = 0.918 - 0.000 = 0.918
# mean compactness = 0.918 - 0.667 = 0.252
# mean concavity = 0.918 - 0.667 = 0.252
# mean concave points = 0.918 - 0.667 = 0.252
# mean symmetry = 0.918 - 0.000 = 0.918
# mean fractal dimension = 0.918 - 0.000 = 0.918
# radius error = 0.918 - 0.000 = 0.918
# texture error = 0.918 - 0.000 = 0.918
# perimeter error = 0.918 - 0.667 = 0.252
# area error = 0.918 - 0.000 = 0.918
# smoothness error = 0.918 - 0.000 = 0.918
# compactness error = 0.918 - 0.918 = 0.000
# concavity error = 0.918 - 0.000 = 0.918
# concave points error = 0.918 - 0.000 = 0.918
# symmetry error = 0.918 - 0.667 = 0.252
# fractal dimension error = 0.918 - 0.000 = 0.918
# worst radius = 0.918 - 0.667 = 0.252
# worst area = 0.918 - 0.667 = 0.252
# worst smoothness = 0.918 - 0.000 = 0.918
# worst compactness = 0.918 - 0.667 = 0.252
# worst concavity = 0.918 - 0.000 = 0.918
# worst concave points = 0.918 - 0.000 = 0.918
# worst symmetry = 0.918 - 0.000 = 0.918
# worst fractal dimension = 0.918 - 0.000 = 0.918
#
# ===Best Feature===
# mean texture
#
# ===Partitioned Dataset (3)===
# Empty DataFrame
# Columns: [mean radius, mean perimeter, mean area, mean smoothness, mean compactness, mean concavity, mean concave points, mean symmetry, mean fractal dimension, radius error, texture error, perimeter error, area error, smoothness error, compactness error, concavity error, concave points error, symmetry error, fractal dimension error, worst radius, worst area, worst smoothness, worst compactness, worst concavity, worst concave points, worst symmetry, worst fractal dimension, target]
# Index: []
#
# [0 rows x 28 columns]
#
# Dataset is empty
#
# ===Partitioned Dataset (8)===
# Empty DataFrame
# Columns: [mean radius, mean perimeter, mean area, mean smoothness, mean compactness, mean concavity, mean concave points, mean symmetry, mean fractal dimension, radius error, texture error, perimeter error, area error, smoothness error, compactness error, concavity error, concave points error, symmetry error, fractal dimension error, worst radius, worst area, worst smoothness, worst compactness, worst concavity, worst concave points, worst symmetry, worst fractal dimension, target]
# Index: []
#
# [0 rows x 28 columns]
#
# Dataset is empty
#
# ===Partitioned Dataset (7)===
#     mean radius mean perimeter mean area mean smoothness mean compactness  \
# 536           4              4         4               3                3
#
#     mean concavity mean concave points mean symmetry mean fractal dimension  \
# 536              5                   4             5                      6
#
#     radius error  ... fractal dimension error worst radius worst area  \
# 536            0  ...                       5            2          2
#
#     worst smoothness worst compactness worst concavity worst concave points  \
# 536                4                 4               5                    3
#
#     worst symmetry worst fractal dimension target
# 536              3                       3      0
#
# [1 rows x 28 columns]
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (1)===
# Empty DataFrame
# Columns: [mean radius, mean perimeter, mean area, mean smoothness, mean compactness, mean concavity, mean concave points, mean symmetry, mean fractal dimension, radius error, texture error, perimeter error, area error, smoothness error, compactness error, concavity error, concave points error, symmetry error, fractal dimension error, worst radius, worst area, worst smoothness, worst compactness, worst concavity, worst concave points, worst symmetry, worst fractal dimension, target]
# Index: []
#
# [0 rows x 28 columns]
#
# Dataset is empty
#
# ===Partitioned Dataset (6)===
# Empty DataFrame
# Columns: [mean radius, mean perimeter, mean area, mean smoothness, mean compactness, mean concavity, mean concave points, mean symmetry, mean fractal dimension, radius error, texture error, perimeter error, area error, smoothness error, compactness error, concavity error, concave points error, symmetry error, fractal dimension error, worst radius, worst area, worst smoothness, worst compactness, worst concavity, worst concave points, worst symmetry, worst fractal dimension, target]
# Index: []
#
# [0 rows x 28 columns]
#
# Dataset is empty
#
# ===Partitioned Dataset (2)===
# Empty DataFrame
# Columns: [mean radius, mean perimeter, mean area, mean smoothness, mean compactness, mean concavity, mean concave points, mean symmetry, mean fractal dimension, radius error, texture error, perimeter error, area error, smoothness error, compactness error, concavity error, concave points error, symmetry error, fractal dimension error, worst radius, worst area, worst smoothness, worst compactness, worst concavity, worst concave points, worst symmetry, worst fractal dimension, target]
# Index: []
#
# [0 rows x 28 columns]
#
# Dataset is empty
#
# ===Partitioned Dataset (0)===
# Empty DataFrame
# Columns: [mean radius, mean perimeter, mean area, mean smoothness, mean compactness, mean concavity, mean concave points, mean symmetry, mean fractal dimension, radius error, texture error, perimeter error, area error, smoothness error, compactness error, concavity error, concave points error, symmetry error, fractal dimension error, worst radius, worst area, worst smoothness, worst compactness, worst concavity, worst concave points, worst symmetry, worst fractal dimension, target]
# Index: []
#
# [0 rows x 28 columns]
#
# Dataset is empty
#
# ===Partitioned Dataset (9)===
#     mean radius mean perimeter mean area mean smoothness mean compactness  \
# 193           2              1         2               3                4
#
#     mean concavity mean concave points mean symmetry mean fractal dimension  \
# 193              4                   3             5                      8
#
#     radius error  ... fractal dimension error worst radius worst area  \
# 193            3  ...                       7            3          3
#
#     worst smoothness worst compactness worst concavity worst concave points  \
# 193                7                 7               5                    4
#
#     worst symmetry worst fractal dimension target
# 193              6                       7      0
#
# [1 rows x 28 columns]
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (5)===
# Empty DataFrame
# Columns: [mean radius, mean perimeter, mean area, mean smoothness, mean compactness, mean concavity, mean concave points, mean symmetry, mean fractal dimension, radius error, texture error, perimeter error, area error, smoothness error, compactness error, concavity error, concave points error, symmetry error, fractal dimension error, worst radius, worst area, worst smoothness, worst compactness, worst concavity, worst concave points, worst symmetry, worst fractal dimension, target]
# Index: []
#
# [0 rows x 28 columns]
#
# Dataset is empty
#
# ===Partitioned Dataset (10)===
#     mean radius mean perimeter mean area mean smoothness mean compactness  \
# 238           4              4         4               1                3
#
#     mean concavity mean concave points mean symmetry mean fractal dimension  \
# 238              4                   3             0                      7
#
#     radius error  ... fractal dimension error worst radius worst area  \
# 238            2  ...                       4            3          3
#
#     worst smoothness worst compactness worst concavity worst concave points  \
# 238                1                 4               3                    1
#
#     worst symmetry worst fractal dimension target
# 238              0                       1      1
#
# [1 rows x 28 columns]
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (4)===
# Empty DataFrame
# Columns: [mean radius, mean perimeter, mean area, mean smoothness, mean compactness, mean concavity, mean concave points, mean symmetry, mean fractal dimension, radius error, texture error, perimeter error, area error, smoothness error, compactness error, concavity error, concave points error, symmetry error, fractal dimension error, worst radius, worst area, worst smoothness, worst compactness, worst concavity, worst concave points, worst symmetry, worst fractal dimension, target]
# Index: []
#
# [0 rows x 28 columns]
#
# Dataset is empty
#
# ===Partitioned Dataset (1)===
# Empty DataFrame
# Columns: [mean radius, mean texture, mean perimeter, mean area, mean smoothness, mean compactness, mean concavity, mean concave points, mean symmetry, mean fractal dimension, radius error, texture error, perimeter error, area error, smoothness error, compactness error, concavity error, concave points error, symmetry error, fractal dimension error, worst radius, worst area, worst smoothness, worst compactness, worst concavity, worst concave points, worst symmetry, worst fractal dimension, target]
# Index: []
#
# [0 rows x 29 columns]
#
# Dataset is empty
#
# ===Partitioned Dataset (2)===
# Empty DataFrame
# Columns: [mean radius, mean texture, mean perimeter, mean area, mean smoothness, mean compactness, mean concavity, mean concave points, mean symmetry, mean fractal dimension, radius error, texture error, perimeter error, area error, smoothness error, compactness error, concavity error, concave points error, symmetry error, fractal dimension error, worst radius, worst area, worst smoothness, worst compactness, worst concavity, worst concave points, worst symmetry, worst fractal dimension, target]
# Index: []
#
# [0 rows x 29 columns]
#
# Dataset is empty
#
# ===Partitioned Dataset (4)===
#   mean radius mean texture mean perimeter mean area mean smoothness  \
# 5           2            1              2         2               5
#
#   mean compactness mean concavity mean concave points mean symmetry  \
# 5                5              6                   6             6
#
#   mean fractal dimension  ... fractal dimension error worst radius worst area  \
# 5                      9  ...                       7            2          3
#
#   worst smoothness worst compactness worst concavity worst concave points  \
# 5                7                 8               6                    5
#
#   worst symmetry worst fractal dimension target
# 5              8                       7      0
#
# [1 rows x 29 columns]
#
# All instances have the same target feature value
#
# CPU times: user 31 s, sys: 830 ms, total: 31.9 s
# Wall time: 31 s

# %%
dt
# Out:
#  worst perimeter (Branch=None)
# 	 mean concavity (Branch=1)
# 		 1 (Branch=1)
# 		 0 (Branch=6)
# 		 mean area (Branch=0)
# 			 1 (Branch=2)
# 			 1 (Branch=6)
# 			 1 (Branch=3)
# 			 0 (Branch=5)
# 			 1 (Branch=0)
# 			 1 (Branch=4)
# 			 1 (Branch=1)
# 		 1 (Branch=4)
# 		 1 (Branch=5)
# 		 1 (Branch=2)
# 		 1 (Branch=3)
# 	 fractal dimension error (Branch=4)
# 		 0 (Branch=8)
# 		 0 (Branch=5)
# 		 0 (Branch=2)
# 		 0 (Branch=1)
# 		 0 (Branch=6)
# 		 0 (Branch=3)
# 		 0 (Branch=4)
# 		 0 (Branch=7)
# 		 mean smoothness (Branch=0)
# 			 1 (Branch=3)
# 			 1 (Branch=5)
# 			 1 (Branch=0)
# 			 1 (Branch=2)
# 			 0 (Branch=1)
# 			 1 (Branch=4)
# 	 worst texture (Branch=3)
# 		 0 (Branch=3)
# 		 mean texture (Branch=8)
# 			 0 (Branch=3)
# 			 0 (Branch=8)
# 			 0 (Branch=7)
# 			 0 (Branch=1)
# 			 0 (Branch=6)
# 			 0 (Branch=2)
# 			 0 (Branch=0)
# 			 1 (Branch=9)
# 			 0 (Branch=5)
# 			 0 (Branch=10)
# 			 0 (Branch=4)
# 		 mean concave points (Branch=7)
# 			 1 (Branch=1)
# 			 0 (Branch=6)
# 			 0 (Branch=0)
# 			 0 (Branch=5)
# 			 0 (Branch=2)
# 			 0 (Branch=4)
# 			 0 (Branch=3)
# 		 0 (Branch=6)
# 		 mean texture (Branch=5)
# 			 1 (Branch=3)
# 			 1 (Branch=8)
# 			 0 (Branch=7)
# 			 1 (Branch=1)
# 			 1 (Branch=6)
# 			 1 (Branch=2)
# 			 1 (Branch=0)
# 			 1 (Branch=9)
# 			 1 (Branch=5)
# 			 1 (Branch=10)
# 			 1 (Branch=4)
# 		 1 (Branch=0)
# 		 0 (Branch=9)
# 		 1 (Branch=1)
# 		 mean texture (Branch=2)
# 			 1 (Branch=3)
# 			 1 (Branch=8)
# 			 1 (Branch=7)
# 			 0 (Branch=1)
# 			 1 (Branch=6)
# 			 1 (Branch=2)
# 			 1 (Branch=0)
# 			 1 (Branch=9)
# 			 1 (Branch=5)
# 			 1 (Branch=10)
# 			 1 (Branch=4)
# 		 1 (Branch=4)
# 	 mean concave points (Branch=0)
# 		 1 (Branch=1)
# 		 1 (Branch=6)
# 		 1 (Branch=0)
# 		 1 (Branch=5)
# 		 radius error (Branch=2)
# 			 1 (Branch=1)
# 			 1 (Branch=4)
# 			 1 (Branch=5)
# 			 1 (Branch=0)
# 			 1 (Branch=2)
# 			 0 (Branch=6)
# 			 1 (Branch=3)
# 		 mean concavity (Branch=4)
# 			 1 (Branch=1)
# 			 1 (Branch=6)
# 			 1 (Branch=0)
# 			 1 (Branch=4)
# 			 1 (Branch=5)
# 			 1 (Branch=2)
# 			 0 (Branch=3)
# 		 1 (Branch=3)
# 	 worst texture (Branch=2)
# 		 1 (Branch=3)
# 		 0 (Branch=8)
# 		 1 (Branch=7)
# 		 mean texture (Branch=6)
# 			 0 (Branch=3)
# 			 0 (Branch=8)
# 			 0 (Branch=7)
# 			 0 (Branch=1)
# 			 0 (Branch=6)
# 			 0 (Branch=2)
# 			 0 (Branch=0)
# 			 0 (Branch=9)
# 			 0 (Branch=5)
# 			 0 (Branch=10)
# 			 1 (Branch=4)
# 		 1 (Branch=5)
# 		 1 (Branch=0)
# 		 mean texture (Branch=9)
# 			 0 (Branch=3)
# 			 0 (Branch=8)
# 			 0 (Branch=7)
# 			 0 (Branch=1)
# 			 0 (Branch=6)
# 			 0 (Branch=2)
# 			 0 (Branch=0)
# 			 0 (Branch=9)
# 			 0 (Branch=5)
# 			 1 (Branch=10)
# 			 0 (Branch=4)
# 		 1 (Branch=1)
# 		 1 (Branch=2)
# 		 0 (Branch=4)

# %%
dt.score(X_test, y_test)
# Out:
# array([[122,   2],
#        [  1,  63]])

# %% [markdown]
# # Random Forest Implementation

# %%
class RandomForest:
    def __init__(self, n_estimators=5, n_sample=2, criterion=None):
        self.n_estimators = n_estimators
        self.n_sample = n_sample
        self.forest = [DecisionTree(criterion=criterion) for _ in range(n_estimators)]

    def sub_sample(self, X, n_sample=2):
        """Enforces feature randomness"""
        return np.random.choice(X.columns.to_numpy(), n_sample, replace=False)

    def bootstrap_sample(self, X, y, n_sample, key=True):
        feature_subset = self.sub_sample(X, int(np.log2(len(X))))
        d = pd.concat([X, y], axis=1)
        d = d.sample(n=n_sample, replace=key)
        return d.iloc[:, :-1][feature_subset], d.iloc[:, -1]

    def fit(self, X, y):
        for tree in self.forest:
            tree.fit(*self.bootstrap_sample(X, y, self.n_sample))
        return self

    def predict(self, x):
        assert all(isinstance(model, DecisionTree) for model in self.forest)
        return mode([dt.predict(x) for dt in self.forest])

    def score(self, X, y):
        y_hat = [self.predict(X.iloc[x].to_frame().T) for x in range(len(X))]
        return confusion_matrix(y, y_hat, labels=[1, 0])

# %%
# %%time

rf = RandomForest(n_estimators=10, n_sample=len(X_train), criterion={'partition_threshold': 5})
rf.fit(X_train, y_train)
# Out:
# ===Information Gain===
# worst smoothness = 0.964 - 0.829 = 0.135
# fractal dimension error = 0.964 - 0.857 = 0.107
# worst compactness = 0.964 - 0.610 = 0.354
# worst symmetry = 0.964 - 0.760 = 0.204
# mean symmetry = 0.964 - 0.800 = 0.164
# worst area = 0.964 - 0.257 = 0.707
# mean perimeter = 0.964 - 0.362 = 0.602
# worst perimeter = 0.964 - 0.245 = 0.719
#
# ===Best Feature===
# worst perimeter
#
# ===Partitioned Dataset (1)===
#     worst smoothness fractal dimension error worst compactness worst symmetry  \
# 111                3                       7                 4              0
# 528                4                       7                 2              0
# 58                 1                       3                 0              2
# 221                4                       3                 4              5
# 81                 6                       7                 7              6
#
#     mean symmetry worst area mean perimeter  target
# 111             3          0              2       1
# 528             5          1              4       1
# 58              4          1              2       1
# 221             5          1              3       1
# 81              5          1              3       1
#
# ===Information Gain===
# worst smoothness = 0.295 - 0.138 = 0.157
# fractal dimension error = 0.295 - 0.234 = 0.061
# worst compactness = 0.295 - 0.093 = 0.203
# worst symmetry = 0.295 - 0.098 = 0.197
# mean symmetry = 0.295 - 0.122 = 0.173
# worst area = 0.295 - 0.284 = 0.011
# mean perimeter = 0.295 - 0.218 = 0.078
#
# ===Best Feature===
# worst compactness
#
# ===Partitioned Dataset (4)===
#     worst smoothness fractal dimension error worst symmetry mean symmetry  \
# 111                3                       7              0             3
# 221                4                       3              5             5
# 480                2                       1              1             1
# 143                3                       1              6             3
# 143                3                       1              6             3
#
#     worst area mean perimeter  target
# 111          0              2       1
# 221          1              3       1
# 480          0              1       1
# 143          1              2       1
# 143          1              2       1
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (3)===
#     worst smoothness fractal dimension error worst symmetry mean symmetry  \
# 267                0                       3              2             2
# 361                2                       1              2             4
# 530                3                       1              2             2
# 149                0                       1              1             1
# 407                0                       8              2             2
#
#     worst area mean perimeter  target
# 267          1              3       1
# 361          1              2       1
# 530          0              1       1
# 149          2              3       1
# 407          1              2       1
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (2)===
#     worst smoothness fractal dimension error worst symmetry mean symmetry  \
# 528                4                       7              0             5
# 545                2                       3              3             2
# 455                2                       3              0             0
# 76                 5                       7              3             6
# 545                2                       3              3             2
#
#     worst area mean perimeter  target
# 528          1              4       1
# 545          2              3       1
# 455          2              3       1
# 76           1              3       1
# 545          2              3       1
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (8)===
#   worst smoothness fractal dimension error worst symmetry mean symmetry  \
# 3                7                       8              8             6
#
#   worst area mean perimeter  target
# 3          1              1       0
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (6)===
#     worst smoothness fractal dimension error worst symmetry mean symmetry  \
# 383                5                       8              4             3
#
#     worst area mean perimeter  target
# 383          1              1       1
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (5)===
#     worst smoothness fractal dimension error worst symmetry mean symmetry  \
# 518                5                       4              2             2
# 518                5                       4              2             2
#
#     worst area mean perimeter  target
# 518          1              2       1
# 518          1              2       1
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (0)===
#    worst smoothness fractal dimension error worst symmetry mean symmetry  \
# 58                1                       3              2             4
# 38                0                       1              0             2
#
#    worst area mean perimeter  target
# 58          1              2       1
# 38          2              4       0
#
# Stopping at 2 instances
#
# ===Partitioned Dataset (7)===
#     worst smoothness fractal dimension error worst symmetry mean symmetry  \
# 81                 6                       7              6             5
# 146                4                       7              8             6
# 208                3                       5              8             4
# 208                3                       5              8             4
# 485                2                       8              6             5
#
#     worst area mean perimeter  target
# 81           1              3       1
# 146          1              1       0
# 208          1              3       1
# 208          1              3       1
# 485          1              2       1
#
# ===Information Gain===
# worst smoothness = 0.985 - 0.000 = 0.985
# fractal dimension error = 0.985 - 0.464 = 0.522
# worst symmetry = 0.985 - 0.694 = 0.292
# mean symmetry = 0.985 - 0.000 = 0.985
# worst area = 0.985 - 0.985 = 0.000
# mean perimeter = 0.985 - 0.000 = 0.985
#
# ===Best Feature===
# worst smoothness
#
# ===Partitioned Dataset (3)===
#     fractal dimension error worst symmetry mean symmetry worst area  \
# 208                       5              8             4          1
# 208                       5              8             4          1
#
#     mean perimeter  target
# 208              3       1
# 208              3       1
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (2)===
#     fractal dimension error worst symmetry mean symmetry worst area  \
# 485                       8              6             5          1
#
#     mean perimeter  target
# 485              2       1
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (1)===
# Empty DataFrame
# Columns: [fractal dimension error, worst symmetry, mean symmetry, worst area, mean perimeter, target]
# Index: []
#
# Dataset is empty
#
# ===Partitioned Dataset (4)===
#     fractal dimension error worst symmetry mean symmetry worst area  \
# 146                       7              8             6          1
# 146                       7              8             6          1
# 146                       7              8             6          1
#
#     mean perimeter  target
# 146              1       0
# 146              1       0
# 146              1       0
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (5)===
# Empty DataFrame
# Columns: [fractal dimension error, worst symmetry, mean symmetry, worst area, mean perimeter, target]
# Index: []
#
# Dataset is empty
#
# ===Partitioned Dataset (7)===
# Empty DataFrame
# Columns: [fractal dimension error, worst symmetry, mean symmetry, worst area, mean perimeter, target]
# Index: []
#
# Dataset is empty
#
# ===Partitioned Dataset (0)===
# Empty DataFrame
# Columns: [fractal dimension error, worst symmetry, mean symmetry, worst area, mean perimeter, target]
# Index: []
#
# Dataset is empty
#
# ===Partitioned Dataset (6)===
#    fractal dimension error worst symmetry mean symmetry worst area  \
# 81                       7              6             5          1
#
#    mean perimeter  target
# 81              3       1
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (1)===
#     worst smoothness fractal dimension error worst symmetry mean symmetry  \
# 287                0                       1              1             0
# 357                2                       1              1             0
# 458                2                       0              1             2
# 552                3                       1              1             2
# 295                2                       1              4             2
#
#     worst area mean perimeter  target
# 287          1              2       1
# 357          2              3       1
# 458          1              2       1
# 552          1              1       1
# 295          1              3       1
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (0)===
#     worst smoothness fractal dimension error worst compactness worst symmetry  \
# 452                2                       6                 3              2
# 559                3                       7                 4              0
# 534                5                       4                 4              1
# 206                5                       2                 2              4
# 314                3                       8                 0              5
#
#     mean symmetry worst area mean perimeter  target
# 452             2          0              1       1
# 559             0          0              0       1
# 534             2          0              0       1
# 206             5          0              0       1
# 314             6          0              0       1
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (3)===
#     worst smoothness fractal dimension error worst compactness worst symmetry  \
# 263                1                       0                 3              3
# 508                3                       2                 2              1
# 8                  7                       5                 8              8
# 112                0                       8                 7              1
# 112                0                       8                 7              1
#
#     mean symmetry worst area mean perimeter  target
# 263             2          4              5       0
# 508             2          4              5       1
# 8               6          3              3       0
# 112             2          2              4       1
# 112             2          2              4       1
#
# ===Information Gain===
# worst smoothness = 0.999 - 0.599 = 0.400
# fractal dimension error = 0.999 - 0.794 = 0.205
# worst compactness = 0.999 - 0.752 = 0.247
# worst symmetry = 0.999 - 0.632 = 0.367
# mean symmetry = 0.999 - 0.727 = 0.272
# worst area = 0.999 - 0.934 = 0.065
# mean perimeter = 0.999 - 0.780 = 0.219
#
# ===Best Feature===
# worst smoothness
#
# ===Partitioned Dataset (3)===
#     fractal dimension error worst compactness worst symmetry mean symmetry  \
# 508                       2                 2              1             2
# 340                       4                 6              5             5
# 340                       4                 6              5             5
# 184                       3                 6              6             3
# 340                       4                 6              5             5
#
#     worst area mean perimeter  target
# 508          4              5       1
# 340          3              4       1
# 340          3              4       1
# 184          4              5       0
# 340          3              4       1
#
# ===Information Gain===
# fractal dimension error = 0.837 - 0.564 = 0.272
# worst compactness = 0.837 - 0.536 = 0.301
# worst symmetry = 0.837 - 0.393 = 0.443
# mean symmetry = 0.837 - 0.423 = 0.413
# worst area = 0.837 - 0.539 = 0.298
# mean perimeter = 0.837 - 0.768 = 0.068
#
# ===Best Feature===
# worst symmetry
#
# ===Partitioned Dataset (0)===
# Empty DataFrame
# Columns: [fractal dimension error, worst compactness, mean symmetry, worst area, mean perimeter, target]
# Index: []
#
# Dataset is empty
#
# ===Partitioned Dataset (2)===
# Empty DataFrame
# Columns: [fractal dimension error, worst compactness, mean symmetry, worst area, mean perimeter, target]
# Index: []
#
# Dataset is empty
#
# ===Partitioned Dataset (3)===
# Empty DataFrame
# Columns: [fractal dimension error, worst compactness, mean symmetry, worst area, mean perimeter, target]
# Index: []
#
# Dataset is empty
#
# ===Partitioned Dataset (1)===
#     fractal dimension error worst compactness mean symmetry worst area  \
# 508                       2                 2             2          4
# 514                       1                 4             2          4
#
#     mean perimeter  target
# 508              5       1
# 514              4       0
#
# Stopping at 2 instances
#
# ===Partitioned Dataset (5)===
#     fractal dimension error worst compactness mean symmetry worst area  \
# 340                       4                 6             5          3
# 340                       4                 6             5          3
# 340                       4                 6             5          3
# 86                        4                 3             5          3
# 225                       0                 2             5          3
#
#     mean perimeter  target
# 340              4       1
# 340              4       1
# 340              4       1
# 86               4       0
# 225              4       1
#
# ===Information Gain===
# fractal dimension error = 0.650 - 0.602 = 0.048
# worst compactness = 0.650 - 0.000 = 0.650
# mean symmetry = 0.650 - 0.650 = 0.000
# worst area = 0.650 - 0.650 = 0.000
# mean perimeter = 0.650 - 0.602 = 0.048
#
# ===Best Feature===
# worst compactness
#
# ===Partitioned Dataset (4)===
#     fractal dimension error mean symmetry worst area mean perimeter  target
# 375                       4             5          3              5       1
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (3)===
#    fractal dimension error mean symmetry worst area mean perimeter  target
# 86                       4             5          3              4       0
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (2)===
#     fractal dimension error mean symmetry worst area mean perimeter  target
# 225                       0             5          3              4       1
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (8)===
# Empty DataFrame
# Columns: [fractal dimension error, mean symmetry, worst area, mean perimeter, target]
# Index: []
#
# Dataset is empty
#
# ===Partitioned Dataset (6)===
#     fractal dimension error mean symmetry worst area mean perimeter  target
# 340                       4             5          3              4       1
# 340                       4             5          3              4       1
# 340                       4             5          3              4       1
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (5)===
# Empty DataFrame
# Columns: [fractal dimension error, mean symmetry, worst area, mean perimeter, target]
# Index: []
#
# Dataset is empty
#
# ===Partitioned Dataset (0)===
# Empty DataFrame
# Columns: [fractal dimension error, mean symmetry, worst area, mean perimeter, target]
# Index: []
#
# Dataset is empty
#
# ===Partitioned Dataset (7)===
# Empty DataFrame
# Columns: [fractal dimension error, mean symmetry, worst area, mean perimeter, target]
# Index: []
#
# Dataset is empty
#
# ===Partitioned Dataset (1)===
# Empty DataFrame
# Columns: [fractal dimension error, mean symmetry, worst area, mean perimeter, target]
# Index: []
#
# Dataset is empty
#
# ===Partitioned Dataset (8)===
# Empty DataFrame
# Columns: [fractal dimension error, worst compactness, mean symmetry, worst area, mean perimeter, target]
# Index: []
#
# Dataset is empty
#
# ===Partitioned Dataset (4)===
#     fractal dimension error worst compactness mean symmetry worst area  \
# 291                       3                 5             4          3
# 291                       3                 5             4          3
# 421                       7                 6             5          3
# 421                       7                 6             5          3
# 291                       3                 5             4          3
#
#     mean perimeter  target
# 291              4       1
# 291              4       1
# 421              4       1
# 421              4       1
# 291              4       1
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (7)===
# Empty DataFrame
# Columns: [fractal dimension error, worst compactness, mean symmetry, worst area, mean perimeter, target]
# Index: []
#
# Dataset is empty
#
# ===Partitioned Dataset (6)===
#     fractal dimension error worst compactness mean symmetry worst area  \
# 184                       3                 6             3          4
# 184                       3                 6             3          4
#
#     mean perimeter  target
# 184              5       0
# 184              5       0
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (2)===
#     fractal dimension error worst compactness worst symmetry mean symmetry  \
# 13                        3                 3              4             4
# 406                       1                 3              3             3
# 347                       3                 3              5             1
# 476                       3                 6              2             1
# 133                       1                 3              3             4
#
#     worst area mean perimeter  target
# 13           3              5       0
# 406          4              5       1
# 347          3              4       1
# 476          3              4       1
# 133          4              5       1
#
# ===Information Gain===
# fractal dimension error = 0.845 - 0.545 = 0.300
# worst compactness = 0.845 - 0.751 = 0.094
# worst symmetry = 0.845 - 0.000 = 0.845
# mean symmetry = 0.845 - 0.441 = 0.404
# worst area = 0.845 - 0.627 = 0.218
# mean perimeter = 0.845 - 0.545 = 0.300
#
# ===Best Feature===
# worst symmetry
#
# ===Partitioned Dataset (0)===
# Empty DataFrame
# Columns: [fractal dimension error, worst compactness, mean symmetry, worst area, mean perimeter, target]
# Index: []
#
# Dataset is empty
#
# ===Partitioned Dataset (2)===
#     fractal dimension error worst compactness mean symmetry worst area  \
# 476                       3                 6             1          3
# 513                       1                 3             3          3
#
#     mean perimeter  target
# 476              4       1
# 513              4       1
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (3)===
#     fractal dimension error worst compactness mean symmetry worst area  \
# 406                       1                 3             3          4
# 133                       1                 3             4          4
# 133                       1                 3             4          4
#
#     mean perimeter  target
# 406              5       1
# 133              5       1
# 133              5       1
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (1)===
#     fractal dimension error worst compactness mean symmetry worst area  \
# 209                       1                 4             0          4
#
#     mean perimeter  target
# 209              4       1
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (5)===
#     fractal dimension error worst compactness mean symmetry worst area  \
# 347                       3                 3             1          3
# 347                       3                 3             1          3
#
#     mean perimeter  target
# 347              4       1
# 347              4       1
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (8)===
# Empty DataFrame
# Columns: [fractal dimension error, worst compactness, mean symmetry, worst area, mean perimeter, target]
# Index: []
#
# Dataset is empty
#
# ===Partitioned Dataset (4)===
#    fractal dimension error worst compactness mean symmetry worst area  \
# 13                       3                 3             4          3
# 13                       3                 3             4          3
# 13                       3                 3             4          3
#
#    mean perimeter  target
# 13              5       0
# 13              5       0
# 13              5       0
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (7)===
# Empty DataFrame
# Columns: [fractal dimension error, worst compactness, mean symmetry, worst area, mean perimeter, target]
# Index: []
#
# Dataset is empty
#
# ===Partitioned Dataset (6)===
# Empty DataFrame
# Columns: [fractal dimension error, worst compactness, mean symmetry, worst area, mean perimeter, target]
# Index: []
#
# Dataset is empty
#
# ===Partitioned Dataset (1)===
#     fractal dimension error worst compactness worst symmetry mean symmetry  \
# 263                       0                 3              3             2
# 542                       3                 2              3             4
# 542                       3                 2              3             4
# 542                       3                 2              3             4
# 542                       3                 2              3             4
#
#     worst area mean perimeter  target
# 263          4              5       0
# 542          3              4       1
# 542          3              4       1
# 542          3              4       1
# 542          3              4       1
#
# ===Information Gain===
# fractal dimension error = 0.722 - 0.000 = 0.722
# worst compactness = 0.722 - 0.000 = 0.722
# worst symmetry = 0.722 - 0.722 = 0.000
# mean symmetry = 0.722 - 0.000 = 0.722
# worst area = 0.722 - 0.000 = 0.722
# mean perimeter = 0.722 - 0.000 = 0.722
#
# ===Best Feature===
# fractal dimension error
#
# ===Partitioned Dataset (7)===
# Empty DataFrame
# Columns: [worst compactness, worst symmetry, mean symmetry, worst area, mean perimeter, target]
# Index: []
#
# Dataset is empty
#
# ===Partitioned Dataset (6)===
# Empty DataFrame
# Columns: [worst compactness, worst symmetry, mean symmetry, worst area, mean perimeter, target]
# Index: []
#
# Dataset is empty
#
# ===Partitioned Dataset (0)===
#     worst compactness worst symmetry mean symmetry worst area mean perimeter  \
# 263                 3              3             2          4              5
#
#      target
# 263       0
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (2)===
# Empty DataFrame
# Columns: [worst compactness, worst symmetry, mean symmetry, worst area, mean perimeter, target]
# Index: []
#
# Dataset is empty
#
# ===Partitioned Dataset (1)===
# Empty DataFrame
# Columns: [worst compactness, worst symmetry, mean symmetry, worst area, mean perimeter, target]
# Index: []
#
# Dataset is empty
#
# ===Partitioned Dataset (5)===
# Empty DataFrame
# Columns: [worst compactness, worst symmetry, mean symmetry, worst area, mean perimeter, target]
# Index: []
#
# Dataset is empty
#
# ===Partitioned Dataset (4)===
# Empty DataFrame
# Columns: [worst compactness, worst symmetry, mean symmetry, worst area, mean perimeter, target]
# Index: []
#
# Dataset is empty
#
# ===Partitioned Dataset (3)===
#     worst compactness worst symmetry mean symmetry worst area mean perimeter  \
# 542                 2              3             4          3              4
# 542                 2              3             4          3              4
# 542                 2              3             4          3              4
# 542                 2              3             4          3              4
#
#      target
# 542       1
# 542       1
# 542       1
# 542       1
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (8)===
# Empty DataFrame
# Columns: [worst compactness, worst symmetry, mean symmetry, worst area, mean perimeter, target]
# Index: []
#
# Dataset is empty
#
# ===Partitioned Dataset (4)===
# Empty DataFrame
# Columns: [fractal dimension error, worst compactness, worst symmetry, mean symmetry, worst area, mean perimeter, target]
# Index: []
#
# Dataset is empty
#
# ===Partitioned Dataset (5)===
#     fractal dimension error worst compactness worst symmetry mean symmetry  \
# 73                        4                 6              2             2
# 329                       7                 4              3             4
# 73                        4                 6              2             2
# 126                       0                 5              6             3
# 73                        4                 6              2             2
#
#     worst area mean perimeter  target
# 73           3              4       0
# 329          4              5       0
# 73           3              4       0
# 126          3              3       0
# 73           3              4       0
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (7)===
#     fractal dimension error worst compactness worst symmetry mean symmetry  \
# 8                         5                 8              8             6
# 501                       8                 7              7             6
# 64                        4                 7              6             5
# 8                         5                 8              8             6
# 501                       8                 7              7             6
#
#     worst area mean perimeter  target
# 8            3              3       0
# 501          3              4       0
# 64           4              2       0
# 8            3              3       0
# 501          3              4       0
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (0)===
#     fractal dimension error worst compactness worst symmetry mean symmetry  \
# 112                       8                 7              1             2
# 112                       8                 7              1             2
# 112                       8                 7              1             2
#
#     worst area mean perimeter  target
# 112          2              4       1
# 112          2              4       1
# 112          2              4       1
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (6)===
#     fractal dimension error worst compactness worst symmetry mean symmetry  \
# 484                       1                 5              2             4
# 255                       3                 6              5             5
# 43                        4                 7              7             5
# 484                       1                 5              2             4
# 512                       5                 7              7             6
#
#     worst area mean perimeter  target
# 484          3              5       1
# 255          3              4       0
# 43           4              3       0
# 484          3              5       1
# 512          3              3       0
#
# ===Information Gain===
# fractal dimension error = 0.764 - 0.000 = 0.764
# worst compactness = 0.764 - 0.000 = 0.764
# worst symmetry = 0.764 - 0.000 = 0.764
# mean symmetry = 0.764 - 0.000 = 0.764
# worst area = 0.764 - 0.671 = 0.093
# mean perimeter = 0.764 - 0.000 = 0.764
#
# ===Best Feature===
# fractal dimension error
#
# ===Partitioned Dataset (7)===
# Empty DataFrame
# Columns: [worst compactness, worst symmetry, mean symmetry, worst area, mean perimeter, target]
# Index: []
#
# Dataset is empty
#
# ===Partitioned Dataset (6)===
# Empty DataFrame
# Columns: [worst compactness, worst symmetry, mean symmetry, worst area, mean perimeter, target]
# Index: []
#
# Dataset is empty
#
# ===Partitioned Dataset (0)===
# Empty DataFrame
# Columns: [worst compactness, worst symmetry, mean symmetry, worst area, mean perimeter, target]
# Index: []
#
# Dataset is empty
#
# ===Partitioned Dataset (2)===
# Empty DataFrame
# Columns: [worst compactness, worst symmetry, mean symmetry, worst area, mean perimeter, target]
# Index: []
#
# Dataset is empty
#
# ===Partitioned Dataset (1)===
#     worst compactness worst symmetry mean symmetry worst area mean perimeter  \
# 484                 5              2             4          3              5
# 484                 5              2             4          3              5
#
#      target
# 484       1
# 484       1
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (5)===
#     worst compactness worst symmetry mean symmetry worst area mean perimeter  \
# 512                 7              7             6          3              3
# 512                 7              7             6          3              3
#
#      target
# 512       0
# 512       0
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (4)===
#    worst compactness worst symmetry mean symmetry worst area mean perimeter  \
# 43                 7              7             5          4              3
# 43                 7              7             5          4              3
#
#     target
# 43       0
# 43       0
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (3)===
#     worst compactness worst symmetry mean symmetry worst area mean perimeter  \
# 255                 6              5             5          3              4
# 255                 6              5             5          3              4
#
#      target
# 255       0
# 255       0
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (8)===
#     worst compactness worst symmetry mean symmetry worst area mean perimeter  \
# 190                 8              8             6          3              4
#
#      target
# 190       0
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (4)===
#     worst smoothness fractal dimension error worst compactness worst symmetry  \
# 134                5                       1                 4              5
# 433                4                       6                 6              5
# 87                 3                       4                 5              8
# 87                 3                       4                 5              8
# 461                3                       6                 7              3
#
#     mean symmetry worst area mean perimeter  target
# 134             2          5              6       0
# 433             5          5              6       0
# 87              5          5              6       0
# 87              5          5              6       0
# 461             5          5              6       0
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (2)===
#     worst smoothness fractal dimension error worst compactness worst symmetry  \
# 298                0                       1                 4              2
# 193                7                       7                 7              6
# 298                0                       1                 4              2
# 385                3                       3                 2              2
# 558                1                       6                 5              1
#
#     mean symmetry worst area mean perimeter  target
# 298             2          3              4       1
# 193             5          3              1       0
# 298             2          3              4       1
# 385             2          3              4       0
# 558             1          2              4       1
#
# ===Information Gain===
# worst smoothness = 0.994 - 0.250 = 0.744
# fractal dimension error = 0.994 - 0.250 = 0.744
# worst compactness = 0.994 - 0.579 = 0.415
# worst symmetry = 0.994 - 0.441 = 0.553
# mean symmetry = 0.994 - 0.549 = 0.445
# worst area = 0.994 - 0.993 = 0.001
# mean perimeter = 0.994 - 0.751 = 0.243
#
# ===Best Feature===
# worst smoothness
#
# ===Partitioned Dataset (3)===
#     fractal dimension error worst compactness worst symmetry mean symmetry  \
# 385                       3                 2              2             2
# 453                       4                 2              2             2
# 385                       3                 2              2             2
#
#     worst area mean perimeter  target
# 385          3              4       0
# 453          3              4       1
# 385          3              4       0
#
# Stopping at 3 instances
#
# ===Partitioned Dataset (2)===
# Empty DataFrame
# Columns: [fractal dimension error, worst compactness, worst symmetry, mean symmetry, worst area, mean perimeter, target]
# Index: []
#
# Dataset is empty
#
# ===Partitioned Dataset (1)===
#     fractal dimension error worst compactness worst symmetry mean symmetry  \
# 558                       6                 5              1             1
#
#     worst area mean perimeter  target
# 558          2              4       1
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (4)===
#     fractal dimension error worst compactness worst symmetry mean symmetry  \
# 536                       5                 4              3             5
#
#     worst area mean perimeter  target
# 536          2              4       0
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (5)===
# Empty DataFrame
# Columns: [fractal dimension error, worst compactness, worst symmetry, mean symmetry, worst area, mean perimeter, target]
# Index: []
#
# Dataset is empty
#
# ===Partitioned Dataset (7)===
#     fractal dimension error worst compactness worst symmetry mean symmetry  \
# 193                       7                 7              6             5
#
#     worst area mean perimeter  target
# 193          3              1       0
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (0)===
#     fractal dimension error worst compactness worst symmetry mean symmetry  \
# 298                       1                 4              2             2
# 298                       1                 4              2             2
# 290                       8                 4              1             2
# 290                       8                 4              1             2
#
#     worst area mean perimeter  target
# 298          3              4       1
# 298          3              4       1
# 290          3              4       1
# 290          3              4       1
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (6)===
#    fractal dimension error worst compactness worst symmetry mean symmetry  \
# 44                       1                 7              7             3
#
#    worst area mean perimeter  target
# 44          3              3       0
#
# All instances have the same target feature value
#
# ===Information Gain===
# mean fractal dimension = 0.960 - 0.923 = 0.037
# worst texture = 0.960 - 0.791 = 0.169
# worst concave points = 0.960 - 0.404 = 0.557
# worst smoothness = 0.960 - 0.764 = 0.197
# worst compactness = 0.960 - 0.636 = 0.325
# worst radius = 0.960 - 0.314 = 0.647
# worst concavity = 0.960 - 0.488 = 0.472
# worst area = 0.960 - 0.314 = 0.646
#
# ===Best Feature===
# worst radius
#
# ===Partitioned Dataset (0)===
#     mean fractal dimension worst texture worst concave points  \
# 144                      3             1                    0
# 248                      7             9                    0
# 68                       9             3                    5
# 478                      7             3                    0
# 390                      7             0                    0
#
#     worst smoothness worst compactness worst concavity worst area  target
# 144                1                 2               0          0       1
# 248                6                 2               0          0       1
# 68                 5                 7               6          0       1
# 478                3                 3               2          0       1
# 390                3                 3               0          0       1
#
# ===Information Gain===
# mean fractal dimension = 0.087 - 0.068 = 0.019
# worst texture = 0.087 - 0.053 = 0.034
# worst concave points = 0.087 - 0.022 = 0.065
# worst smoothness = 0.087 - 0.036 = 0.052
# worst compactness = 0.087 - 0.060 = 0.027
# worst concavity = 0.087 - 0.022 = 0.065
# worst area = 0.087 - 0.087 = 0.000
#
# ===Best Feature===
# worst concave points
#
# ===Partitioned Dataset (0)===
#     mean fractal dimension worst texture worst smoothness worst compactness  \
# 144                      3             1                1                 2
# 248                      7             9                6                 2
# 478                      7             3                3                 3
# 390                      7             0                3                 3
# 55                       5             3                3                 0
#
#     worst concavity worst area  target
# 144               0          0       1
# 248               0          0       1
# 478               2          0       1
# 390               0          0       1
# 55                0          0       1
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (2)===
#     mean fractal dimension worst texture worst smoothness worst compactness  \
# 382                      8             7                0                 5
# 410                      5             9                5                 2
# 534                      7             6                5                 4
# 293                      3             5                4                 3
# 320                      8             1                5                 4
#
#     worst concavity worst area  target
# 382               3          0       1
# 410               1          0       1
# 534               2          0       1
# 293               0          0       1
# 320               1          0       1
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (5)===
#    mean fractal dimension worst texture worst smoothness worst compactness  \
# 68                      9             3                5                 7
# 68                      9             3                5                 7
# 68                      9             3                5                 7
#
#    worst concavity worst area  target
# 68               6          0       1
# 68               6          0       1
# 68               6          0       1
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (1)===
#     mean fractal dimension worst texture worst smoothness worst compactness  \
# 98                       7             0                5                 3
# 525                      8             0                6                 4
# 137                      4             3                2                 3
# 547                      8             3                5                 4
# 388                      8             0                1                 4
#
#     worst concavity worst area  target
# 98                1          0       1
# 525               1          0       1
# 137               0          0       1
# 547               1          0       1
# 388               3          0       1
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (4)===
#     mean fractal dimension worst texture worst smoothness worst compactness  \
# 152                      9             1                3                 4
# 41                       8             9                7                 4
#
#     worst concavity worst area  target
# 152               6          0       1
# 41                5          0       0
#
# Stopping at 2 instances
#
# ===Partitioned Dataset (3)===
#     mean fractal dimension worst texture worst smoothness worst compactness  \
# 242                      9             7                3                 7
# 106                      7             7                7                 4
# 106                      7             7                7                 4
#
#     worst concavity worst area  target
# 242               6          0       1
# 106               3          0       1
# 106               3          0       1
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (1)===
#     mean fractal dimension worst texture worst concave points  \
# 360                      0             2                    0
# 200                      6             7                    2
# 143                      7             2                    2
# 211                      7             5                    0
# 397                      4             2                    1
#
#     worst smoothness worst compactness worst concavity worst area  target
# 360                0                 0               0          1       1
# 200                5                 3               0          1       1
# 143                3                 4               2          1       1
# 211                3                 3               1          0       1
# 397                0                 3               1          1       1
#
# ===Information Gain===
# mean fractal dimension = 0.371 - 0.233 = 0.138
# worst texture = 0.371 - 0.202 = 0.169
# worst concave points = 0.371 - 0.206 = 0.165
# worst smoothness = 0.371 - 0.177 = 0.194
# worst compactness = 0.371 - 0.219 = 0.152
# worst concavity = 0.371 - 0.244 = 0.128
# worst area = 0.371 - 0.340 = 0.032
#
# ===Best Feature===
# worst smoothness
#
# ===Partitioned Dataset (1)===
#     mean fractal dimension worst texture worst concave points  \
# 377                      4             9                    0
# 102                      3             9                    0
# 51                       6             3                    2
# 301                      7             3                    1
# 58                       1             3                    0
#
#     worst compactness worst concavity worst area  target
# 377                 2               0          1       1
# 102                 0               0          0       1
# 51                  2               0          1       1
# 301                 4               1          0       1
# 58                  0               0          1       1
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (0)===
#     mean fractal dimension worst texture worst concave points  \
# 360                      0             2                    0
# 397                      4             2                    1
# 267                      4             8                    0
# 407                      7             6                    0
# 308                      0             0                    0
#
#     worst compactness worst concavity worst area  target
# 360                 0               0          1       1
# 397                 3               1          1       1
# 267                 3               0          1       1
# 407                 3               1          1       1
# 308                 0               0          2       1
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (5)===
#     mean fractal dimension worst texture worst concave points  \
# 200                      6             7                    2
# 76                       7             0                    0
# 292                      7             1                    2
# 394                      7             5                    0
# 154                      7             1                    2
#
#     worst compactness worst concavity worst area  target
# 200                 3               0          1       1
# 76                  2               0          1       1
# 292                 4               2          1       1
# 394                 3               1          1       1
# 154                 4               3          1       1
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (3)===
#     mean fractal dimension worst texture worst concave points  \
# 143                      7             2                    2
# 211                      7             5                    0
# 530                      8             7                    2
# 150                      7             4                    0
# 247                      7             0                    4
#
#     worst compactness worst concavity worst area  target
# 143                 4               2          1       1
# 211                 3               1          0       1
# 530                 3               0          0       1
# 150                 1               0          1       1
# 247                 8               6          1       1
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (6)===
#     mean fractal dimension worst texture worst concave points  \
# 502                      7             2                    1
# 496                      8             3                    3
# 115                      7             6                    0
# 502                      7             2                    1
# 48                       6             1                    0
#
#     worst compactness worst concavity worst area  target
# 502                 3               1          0       1
# 496                 7               4          1       1
# 115                 4               1          1       1
# 502                 3               1          0       1
# 48                  4               3          1       1
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (2)===
#     mean fractal dimension worst texture worst concave points  \
# 403                      7             3                    1
# 334                      6             7                    0
# 107                      7             7                    1
# 458                      1             8                    0
# 334                      6             7                    0
#
#     worst compactness worst concavity worst area  target
# 403                 3               1          1       1
# 334                 0               0          0       1
# 107                 3               1          0       1
# 458                 1               0          1       1
# 334                 0               0          0       1
#
# ===Information Gain===
# mean fractal dimension = 0.811 - 0.431 = 0.380
# worst texture = 0.811 - 0.000 = 0.811
# worst concave points = 0.811 - 0.650 = 0.161
# worst compactness = 0.811 - 0.431 = 0.380
# worst concavity = 0.811 - 0.650 = 0.161
# worst area = 0.811 - 0.689 = 0.123
#
# ===Best Feature===
# worst texture
#
# ===Partitioned Dataset (1)===
# Empty DataFrame
# Columns: [mean fractal dimension, worst concave points, worst compactness, worst concavity, worst area, target]
# Index: []
#
# Dataset is empty
#
# ===Partitioned Dataset (2)===
# Empty DataFrame
# Columns: [mean fractal dimension, worst concave points, worst compactness, worst concavity, worst area, target]
# Index: []
#
# Dataset is empty
#
# ===Partitioned Dataset (7)===
#     mean fractal dimension worst concave points worst compactness  \
# 334                      6                    0                 0
# 107                      7                    1                 3
# 334                      6                    0                 0
# 334                      6                    0                 0
# ...
# Index: []
#
# Dataset is empty
#
# ===Partitioned Dataset (0)===
#     worst compactness worst symmetry texture error mean symmetry worst area  \
# 508                 2              1             0             2          4
# 514                 4              1             5             2          4
# 513                 3              2             1             3          3
# 86                  3              5             9             5          3
# 13                  3              4             4             4          3
#
#     smoothness error  target
# 508                5       1
# 514                1       0
# 513                1       1
# 86                 5       0
# 13                 5       0
#
# ===Information Gain===
# worst compactness = 0.985 - 0.432 = 0.554
# worst symmetry = 0.985 - 0.490 = 0.496
# texture error = 0.985 - 0.000 = 0.985
# mean symmetry = 0.985 - 0.747 = 0.238
# worst area = 0.985 - 0.974 = 0.011
# smoothness error = 0.985 - 0.778 = 0.207
#
# ===Best Feature===
# texture error
#
# ===Partitioned Dataset (8)===
# Empty DataFrame
# Columns: [worst compactness, worst symmetry, mean symmetry, worst area, smoothness error, target]
# Index: []
#
# Dataset is empty
#
# ===Partitioned Dataset (9)===
#    worst compactness worst symmetry mean symmetry worst area smoothness error  \
# 86                 3              5             5          3                5
#
#     target
# 86       0
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (2)===
# Empty DataFrame
# Columns: [worst compactness, worst symmetry, mean symmetry, worst area, smoothness error, target]
# Index: []
#
# Dataset is empty
#
# ===Partitioned Dataset (0)===
#     worst compactness worst symmetry mean symmetry worst area  \
# 508                 2              1             2          4
# 508                 2              1             2          4
#
#     smoothness error  target
# 508                5       1
# 508                5       1
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (1)===
#     worst compactness worst symmetry mean symmetry worst area  \
# 513                 3              2             3          3
# 406                 3              3             3          4
# 225                 2              5             5          3
#
#     smoothness error  target
# 513                1       1
# 406                0       1
# 225                4       1
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (6)===
#     worst compactness worst symmetry mean symmetry worst area  \
# 542                 2              3             4          3
#
#     smoothness error  target
# 542                1       1
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (3)===
# Empty DataFrame
# Columns: [worst compactness, worst symmetry, mean symmetry, worst area, smoothness error, target]
# Index: []
#
# Dataset is empty
#
# ===Partitioned Dataset (5)===
#     worst compactness worst symmetry mean symmetry worst area  \
# 514                 4              1             2          4
# 514                 4              1             2          4
# 514                 4              1             2          4
#
#     smoothness error  target
# 514                1       0
# 514                1       0
# 514                1       0
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (4)===
#    worst compactness worst symmetry mean symmetry worst area smoothness error  \
# 13                 3              4             4          3                5
# 13                 3              4             4          3                5
# 13                 3              4             4          3                5
# 13                 3              4             4          3                5
#
#     target
# 13       0
# 13       0
# 13       0
# 13       0
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (7)===
# Empty DataFrame
# Columns: [worst compactness, worst symmetry, mean symmetry, worst area, smoothness error, target]
# Index: []
#
# Dataset is empty
#
# ===Partitioned Dataset (1)===
#     worst compactness worst symmetry texture error mean symmetry worst area  \
# 209                 4              1             0             0          4
# 148                 4              3             1             3          3
# 148                 4              3             1             3          3
#
#     smoothness error  target
# 209                0       1
# 148                2       1
# 148                2       1
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (6)===
#     worst compactness worst symmetry texture error mean symmetry worst area  \
# 43                  7              7             2             5          4
# 7                   7              6             6             6          4
# 64                  7              6             5             5          4
# 541                 7              6             5             4          3
# 7                   7              6             6             6          4
#
#     smoothness error  target
# 43                 1       0
# 7                  5       0
# 64                 5       0
# 541                4       1
# 7                  5       0
#
# ===Information Gain===
# worst compactness = 0.845 - 0.801 = 0.044
# worst symmetry = 0.845 - 0.295 = 0.550
# texture error = 0.845 - 0.250 = 0.595
# mean symmetry = 0.845 - 0.432 = 0.413
# worst area = 0.845 - 0.250 = 0.595
# smoothness error = 0.845 - 0.441 = 0.404
#
# ===Best Feature===
# texture error
#
# ===Partitioned Dataset (8)===
# Empty DataFrame
# Columns: [worst compactness, worst symmetry, mean symmetry, worst area, smoothness error, target]
# Index: []
#
# Dataset is empty
#
# ===Partitioned Dataset (9)===
# Empty DataFrame
# Columns: [worst compactness, worst symmetry, mean symmetry, worst area, smoothness error, target]
# Index: []
#
# Dataset is empty
#
# ===Partitioned Dataset (2)===
#    worst compactness worst symmetry mean symmetry worst area smoothness error  \
# 43                 7              7             5          4                1
# 43                 7              7             5          4                1
#
#     target
# 43       0
# 43       0
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (0)===
# Empty DataFrame
# Columns: [worst compactness, worst symmetry, mean symmetry, worst area, smoothness error, target]
# Index: []
#
# Dataset is empty
#
# ===Partitioned Dataset (1)===
#    worst compactness worst symmetry mean symmetry worst area smoothness error  \
# 73                 6              2             2          3                1
#
#     target
# 73       0
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (6)===
#   worst compactness worst symmetry mean symmetry worst area smoothness error  \
# 7                 7              6             6          4                5
# 7                 7              6             6          4                5
#
#    target
# 7       0
# 7       0
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (3)===
#    worst compactness worst symmetry mean symmetry worst area smoothness error  \
# 36                 7              7             4          3                2
#
#     target
# 36       0
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (5)===
#     worst compactness worst symmetry mean symmetry worst area  \
# 64                  7              6             5          4
# 541                 7              6             4          3
# 57                  7              7             5          4
#
#     smoothness error  target
# 64                 5       0
# 541                4       1
# 57                 0       0
#
# Stopping at 3 instances
#
# ===Partitioned Dataset (4)===
# Empty DataFrame
# Columns: [worst compactness, worst symmetry, mean symmetry, worst area, smoothness error, target]
# Index: []
#
# Dataset is empty
#
# ===Partitioned Dataset (7)===
#     worst compactness worst symmetry mean symmetry worst area  \
# 112                 7              1             2          2
# 112                 7              1             2          2
#
#     smoothness error  target
# 112                1       1
# 112                1       1
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (5)===
#     worst compactness worst symmetry texture error mean symmetry worst area  \
# 99                  5              3             8             4          3
# 99                  5              3             8             4          3
# 99                  5              3             8             4          3
# 184                 6              6             0             3          4
#
#     smoothness error  target
# 99                 5       0
# 99                 5       0
# 99                 5       0
# 184                0       0
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (4)===
#     worst compactness worst symmetry texture error mean symmetry worst area  \
# 421                 6              4             7             5          3
# 147                 4              4             8             3          3
# 147                 4              4             8             3          3
#
#     smoothness error  target
# 421                5       1
# 147                2       1
# 147                2       1
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (3)===
#     worst compactness worst symmetry texture error mean symmetry worst area  \
# 89                  5              5             1             6          3
# 291                 5              4             2             4          3
# 291                 5              4             2             4          3
# 89                  5              5             1             6          3
# 500                 4              0             2             2          3
#
#     smoothness error  target
# 89                 1       1
# 291                1       1
# 291                1       1
# 89                 1       1
# 500                0       1
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (7)===
#     worst compactness worst symmetry texture error mean symmetry worst area  \
# 105                 7              5             2             5          3
# 190                 8              8             8             6          3
# 190                 8              8             8             6          3
#
#     smoothness error  target
# 105                4       0
# 190                5       0
# 190                5       0
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (2)===
#     worst compactness worst fractal dimension worst symmetry texture error  \
# 44                  7                       5              7             1
# 481                 2                       1              1             2
# 44                  7                       5              7             1
# 169                 3                       0              1             5
# 165                 1                       0              3             4
#
#     mean symmetry worst area smoothness error  target
# 44              3          3                0       0
# 481             2          3                0       1
# 44              3          3                0       0
# 169             3          3                1       1
# 165             1          3                0       1
#
# ===Information Gain===
# worst compactness = 0.831 - 0.276 = 0.555
# worst fractal dimension = 0.831 - 0.468 = 0.363
# worst symmetry = 0.831 - 0.363 = 0.468
# texture error = 0.831 - 0.426 = 0.405
# mean symmetry = 0.831 - 0.536 = 0.295
# worst area = 0.831 - 0.781 = 0.050
# smoothness error = 0.831 - 0.507 = 0.324
#
# ===Best Feature===
# worst compactness
#
# ===Partitioned Dataset (7)===
#     worst fractal dimension worst symmetry texture error mean symmetry  \
# 44                        5              7             1             3
# 44                        5              7             1             3
# 215                       6              7             5             6
#
#     worst area smoothness error  target
# 44           3                0       0
# 44           3                0       0
# 215          3                2       0
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (0)===
# Empty DataFrame
# Columns: [worst fractal dimension, worst symmetry, texture error, mean symmetry, worst area, smoothness error, target]
# Index: []
#
# Dataset is empty
#
# ===Partitioned Dataset (3)===
#     worst fractal dimension worst symmetry texture error mean symmetry  \
# 169                       0              1             5             3
# 371                       0              2             0             3
# 169                       0              1             5             3
# 371                       0              2             0             3
#
#     worst area smoothness error  target
# 169          3                1       1
# 371          3                1       1
# 169          3                1       1
# 371          3                1       1
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (2)===
#     worst fractal dimension worst symmetry texture error mean symmetry  \
# 481                       1              1             2             2
# 481                       1              1             2             2
# 385                       0              2             7             2
# 453                       1              2             1             2
#
#     worst area smoothness error  target
# 481          3                0       1
# 481          3                0       1
# 385          3                5       0
# 453          3                2       1
#
# Stopping at 4 instances
#
# ===Partitioned Dataset (8)===
#     worst fractal dimension worst symmetry texture error mean symmetry  \
# 247                       6              2             0             2
# 247                       6              2             0             2
#
#     worst area smoothness error  target
# 247          1                1       1
# 247          1                1       1
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (4)===
#     worst fractal dimension worst symmetry texture error mean symmetry  \
# 536                       3              3             8             5
# 298                       1              2             1             2
#
#     worst area smoothness error  target
# 536          2                2       0
# 298          3                0       1
#
# Stopping at 2 instances
#
# ===Partitioned Dataset (1)===
#     worst fractal dimension worst symmetry texture error mean symmetry  \
# 165                       0              3             4             1
# 165                       0              3             4             1
#
#     worst area smoothness error  target
# 165          3                0       1
# 165          3                0       1
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (5)===
#     worst fractal dimension worst symmetry texture error mean symmetry  \
# 558                       2              1             5             1
# 526                       3              6             1             3
#
#     worst area smoothness error  target
# 558          2                0       1
# 526          2                0       1
#
# All instances have the same target feature value
#
# ===Partitioned Dataset (6)===
# Empty DataFrame
# Columns: [worst fractal dimension, worst symmetry, texture error, mean symmetry, worst area, smoothness error, target]
# Index: []
#
# Dataset is empty
#
# CPU times: user 24.5 s, sys: 285 ms, total: 24.7 s
# Wall time: 24.8 s

# %%
rf.score(X_test, y_test)
# Out:
# array([[123,   1],
#        [  2,  62]])
